# %% [markdown]
# # Mock Belt Exam - Data Enrichment

# %% [markdown]
# - 09/02/22
# - Purvi Kansara

# %% [markdown]
# ## Instructions

# %% [markdown]
# Data Enrichment Mock Exam
#
# API results:
#
# https://drive.google.com/file/d/1zyVYMuS8GsgoZhWQpBp-5ijlzS3FknKE/view
#
# 1. Read in the json file
# 2. Separate the records into 4 tables each a pandas dataframe
# 3. Transform
#     In this case remove dollar signs from funded amount in the financials records and convert to numeric datatype
# 4. Create a database with SQLAlchemy and add the tables to the datbase
# 5. Open MySQL workbench and export the .sql file
# 6. Perform a hypothesis test to determine if there is a signficant difference between the funded amount when it is all males and when there is at least one female in the group.

# %% [markdown]
# # ETL of JSON File

# %%
import json
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats


import pymysql
pymysql.install_as_MySQLdb()

from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists

# %% [markdown]
# ## Extract

# %%
## Loading json file
## Loading json file
with open("Mock_Crowdsourcing_API_Results.json") as f:
    jsondata= json.load(f)
type(jsondata)
# Out:
# dict

# %%
## explore each key 
jsondata.keys()
# Out:
# dict_keys(['meta', 'data'])

# %%
## display meta

jsondata['meta']
# Out:
# 'Practice Lesson: Mock API Call'

# %%
## display data
type(jsondata['data'])
# Out:
# dict

# %%
## preview the dictionary
jsondata['data'].keys()
# Out:
# dict_keys(['crowd', 'demographics', 'financials', 'use'])

# %%
## what does the crowd key look like?
type(jsondata['data']['crowd'])
# Out:
# list

# %%
jsondata['data']['crowd']
# Out:
# [{'id': 658776,
#   'posted_time': '2014-01-17 21:21:10+00:00',
#   'funded_time': '2014-02-05 17:57:55+00:00',
#   'lender_count': 33},
#  {'id': 1314847,
#   'posted_time': '2017-06-07 02:02:41+00:00',
#   'funded_time': '2017-06-21 17:10:38+00:00',
#   'lender_count': 9},
#  {'id': 863063,
#   'posted_time': '2015-03-27 20:08:04+00:00',
#   'funded_time': '2015-04-04 15:01:22+00:00',
#   'lender_count': 1},
#  {'id': 1184347,
#   'posted_time': '2016-11-14 07:32:12+00:00',
#   'funded_time': '2016-11-25 03:07:13+00:00',
#   'lender_count': 47},
#  {'id': 729745,
#   'posted_time': '2014-06-24 07:35:46+00:00',
#   'funded_time': '2014-07-10 16:12:43+00:00',
#   'lender_count': 12},
#  {'id': 766484,
#   'posted_time': '2014-09-10 08:24:26+00:00',
#   'funded_time': '2014-09-21 14:23:33+00:00',
#   'lender_count': 14},
#  {'id': 1133162,
#   'posted_time': '2016-08-15 08:27:55+00:00',
#   'funded_time': '2016-09-18 11:52:49+00:00',
#   'lender_count': 20},
#  {'id': 1152653,
#   'posted_time': '2016-09-19 07:58:58+00:00',
#   'funded_time': '2016-09-21 21:12:39+00:00',
#   'lender_count': 13},
#  {'id': 1070561,
#   'posted_time': '2016-05-18 00:24:47+00:00',
#   'funded_time': '2016-06-15 03:24:38+00:00',
#   'lender_count': 22},
#  {'id': 1321354,
#   'posted_time': '2017-06-16 09:45:01+00:00',
#   'funded_time': '2017-06-26 14:13:11+00:00',
#   'lender_count': 23},
#  {'id': 685876,
#   'posted_time': '2014-03-19 08:47:31+00:00',
#   'funded_time': '2014-03-21 18:54:49+00:00',
#   'lender_count': 18},
#  {'id': 1063415,
#   'posted_time': '2016-05-02 06:55:33+00:00',
#   'funded_time': '2016-05-05 02:54:25+00:00',
#   'lender_count': 6},
#  {'id': 686921,
#   'posted_time': '2014-03-21 00:26:18+00:00',
#   'funded_time': '2014-03-23 23:46:54+00:00',
#   'lender_count': 18},
#  {'id': 977552,
#   'posted_time': '2015-11-12 07:31:01+00:00',
#   'funded_time': '2015-12-10 01:56:40+00:00',
#   'lender_count': 17},
#  {'id': 836963,
#   'posted_time': '2015-02-06 07:52:29+00:00',
#   'funded_time': '2015-02-17 15:00:52+00:00',
#   'lender_count': 11},
#  {'id': 745657,
#   'posted_time': '2014-07-28 02:53:49+00:00',
#   'funded_time': '2014-08-08 21:04:22+00:00',
#   'lender_count': 6},
#  {'id': 1136589,
#   'posted_time': '2016-08-21 05:41:50+00:00',
#   'funded_time': '2016-08-30 04:09:26+00:00',
#   'lender_count': 14},
#  {'id': 1156199,
#   'posted_time': '2016-09-23 06:54:33+00:00',
#   'funded_time': '2016-09-30 03:15:35+00:00',
#   'lender_count': 9},
#  {'id': 848859,
#   'posted_time': '2015-03-02 03:11:49+00:00',
#   'funded_time': '2015-03-20 18:04:11+00:00',
#   'lender_count': 30},
#  {'id': 1191351,
#   'posted_time': '2016-11-23 12:31:45+00:00',
#   'funded_time': '2016-11-30 04:53:17+00:00',
#   'lender_count': 6},
#  {'id': 1049704,
#   'posted_time': '2016-04-05 11:28:14+00:00',
#   'funded_time': '2016-04-09 12:41:08+00:00',
#   'lender_count': 9},
#  {'id': 855669,
#   'posted_time': '2015-03-16 05:46:00+00:00',
#   'funded_time': '2015-03-20 17:55:40+00:00',
#   'lender_count': 11},
#  {'id': 1040492,
#   'posted_time': '2016-03-17 17:32:13+00:00',
#   'funded_time': '2016-03-21 11:15:32+00:00',
#   'lender_count': 3},
#  {'id': 883638,
#   'posted_time': '2015-05-12 06:18:55+00:00',
#   'funded_time': '2015-05-14 05:27:18+00:00',
#   'lender_count': 6},
#  {'id': 1336206,
#   'posted_time': '2017-07-07 23:00:50+00:00',
#   'funded_time': None,
#   'lender_count': 3},
#  {'id': 806147,
#   'posted_time': '2014-11-26 12:04:02+00:00',
#   'funded_time': '2014-12-01 00:00:57+00:00',
#   'lender_count': 3},
#  {'id': 1220247,
#   'posted_time': '2017-01-13 18:50:38+00:00',
#   'funded_time': '2017-01-24 15:06:01+00:00',
#   'lender_count': 26},
#  {'id': 690566,
#   'posted_time': '2014-03-28 15:22:40+00:00',
#   'funded_time': '2014-04-24 18:32:00+00:00',
#   'lender_count': 74},
#  {'id': 1219165,
#   'posted_time': '2017-01-12 07:50:58+00:00',
#   'funded_time': '2017-01-12 16:25:13+00:00',
#   'lender_count': 1},
#  {'id': 1183722,
#   'posted_time': '2016-11-11 15:19:08+00:00',
#   'funded_time': '2016-11-19 07:58:02+00:00',
#   'lender_count': 10},
#  {'id': 693712,
#   'posted_time': '2014-04-04 15:21:31+00:00',
#   'funded_time': '2014-04-23 00:30:31+00:00',
#   'lender_count': 37},
#  {'id': 961892,
#   'posted_time': '2015-10-12 23:33:32+00:00',
#   'funded_time': '2015-10-24 19:24:14+00:00',
#   'lender_count': 47},
#  {'id': 1049857,
#   'posted_time': '2016-04-05 22:36:52+00:00',
#   'funded_time': '2016-04-13 07:49:21+00:00',
#   'lender_count': 5},
#  {'id': 1009912,
#   'posted_time': '2016-01-18 14:28:23+00:00',
#   'funded_time': '2016-01-21 15:52:25+00:00',
#   'lender_count': 53},
#  {'id': 1117335,
#   'posted_time': '2016-07-16 01:57:24+00:00',
#   'funded_time': '2016-07-26 21:25:03+00:00',
#   'lender_count': 33},
#  {'id': 794407,
#   'posted_time': '2014-11-05 20:34:18+00:00',
#   'funded_time': '2014-11-20 02:50:16+00:00',
#   'lender_count': 12},
#  {'id': 709984,
#   'posted_time': '2014-05-14 14:23:07+00:00',
#   'funded_time': '2014-05-24 20:03:12+00:00',
#   'lender_count': 9},
#  {'id': 1218721,
#   'posted_time': '2017-01-11 12:42:30+00:00',
#   'funded_time': '2017-01-12 13:30:06+00:00',
#   'lender_count': 5},
#  {'id': 1241565,
#   'posted_time': '2017-02-20 01:29:35+00:00',
#   'funded_time': '2017-02-25 05:28:42+00:00',
#   'lender_count': 3},
#  {'id': 874836,
#   'posted_time': '2015-04-23 13:23:04+00:00',
#   'funded_time': '2015-05-20 09:23:08+00:00',
#   'lender_count': 9},
#  {'id': 1163035,
#   'posted_time': '2016-10-05 08:03:12+00:00',
#   'funded_time': None,
#   'lender_count': 23},
#  {'id': 792308,
#   'posted_time': '2014-10-31 06:11:25+00:00',
#   'funded_time': '2014-11-09 02:15:42+00:00',
#   'lender_count': 4},
#  {'id': 693949,
#   'posted_time': '2014-04-05 15:40:57+00:00',
#   'funded_time': None,
#   'lender_count': 22},
#  {'id': 933803,
#   'posted_time': '2015-08-18 06:27:01+00:00',
#   'funded_time': '2015-08-19 18:13:20+00:00',
#   'lender_count': 8},
#  {'id': 807949,
#   'posted_time': '2014-11-28 20:43:01+00:00',
#   'funded_time': None,
#   'lender_count': 11},
#  {'id': 733201,
#   'posted_time': '2014-07-01 13:38:18+00:00',
#   'funded_time': '2014-07-07 17:06:23+00:00',
#   'lender_count': 12},
#  {'id': 1294509,
#   'posted_time': '2017-05-09 03:46:31+00:00',
#   'funded_time': '2017-05-19 15:54:01+00:00',
#   'lender_count': 12},
#  {'id': 790621,
#   'posted_time': '2014-10-28 22:50:57+00:00',
#   'funded_time': '2014-11-19 01:38:54+00:00',
#   'lender_count': 2},
#  {'id': 1090356,
#   'posted_time': '2015-10-23 15:01:03+00:00',
#   'funded_time': None,
#   'lender_count': 5},
#  {'id': 1131838,
#   'posted_time': '2016-08-11 07:01:17+00:00',
#   'funded_time': '2016-08-21 07:33:50+00:00',
#   'lender_count': 13},
#  {'id': 697576,
#   'posted_time': '2014-04-14 10:50:56+00:00',
#   'funded_time': '2014-04-16 13:21:26+00:00',
#   'lender_count': 19},
#  {'id': 1233814,
#   'posted_time': '2017-02-07 15:29:26+00:00',
#   'funded_time': '2017-02-13 09:22:41+00:00',
#   'lender_count': 16},
#  {'id': 1081411,
#   'posted_time': '2014-05-18 12:44:58+00:00',
#   'funded_time': '2014-05-21 03:25:00+00:00',
#   'lender_count': 13},
#  {'id': 668335,
#   'posted_time': '2014-02-11 12:14:54+00:00',
#   'funded_time': '2014-02-22 00:14:23+00:00',
#   'lender_count': 46},
#  {'id': 672061,
#   'posted_time': '2014-02-18 13:22:13+00:00',
#   'funded_time': '2014-03-13 02:37:25+00:00',
#   'lender_count': 31},
#  {'id': 1196818,
#   'posted_time': '2016-12-01 05:29:07+00:00',
#   'funded_time': '2016-12-07 19:45:12+00:00',
#   'lender_count': 1},
#  {'id': 1304378,
#   'posted_time': '2017-05-23 09:29:42+00:00',
#   'funded_time': '2017-06-07 23:30:51+00:00',
#   'lender_count': 34},
#  {'id': 709624,
#   'posted_time': '2014-05-14 03:23:42+00:00',
#   'funded_time': '2014-05-16 22:43:08+00:00',
#   'lender_count': 27},
#  {'id': 782869,
#   'posted_time': '2014-10-14 12:06:53+00:00',
#   'funded_time': '2014-10-25 14:36:39+00:00',
#   'lender_count': 3},
#  {'id': 876662,
#   'posted_time': '2015-04-27 13:21:29+00:00',
#   'funded_time': '2015-06-02 05:14:50+00:00',
#   'lender_count': 9},
#  {'id': 893915,
#   'posted_time': '2015-05-29 01:23:46+00:00',
#   'funded_time': '2015-07-18 14:09:51+00:00',
#   'lender_count': 126},
#  {'id': 666512,
#   'posted_time': '2014-02-07 01:34:43+00:00',
#   'funded_time': '2014-02-10 16:55:56+00:00',
#   'lender_count': 47},
#  {'id': 836666,
#   'posted_time': '2015-02-05 13:25:34+00:00',
#   'funded_time': '2015-02-17 17:56:01+00:00',
#   'lender_count': 32},
#  {'id': 1036590,
#   'posted_time': '2016-03-10 15:42:30+00:00',
#   'funded_time': '2016-03-17 17:28:12+00:00',
#   'lender_count': 5},
#  {'id': 1183193,
#   'posted_time': '2016-11-10 12:52:18+00:00',
#   'funded_time': '2016-12-10 23:20:16+00:00',
#   'lender_count': 53},
#  {'id': 1172495,
#   'posted_time': '2016-10-21 21:14:15+00:00',
#   'funded_time': '2016-11-29 14:21:00+00:00',
#   'lender_count': 19},
#  {'id': 807115,
#   'posted_time': '2014-11-27 16:07:23+00:00',
#   'funded_time': '2015-01-24 18:11:57+00:00',
#   'lender_count': 34},
#  {'id': 915255,
#   'posted_time': '2015-07-09 11:49:34+00:00',
#   'funded_time': '2015-07-13 19:14:04+00:00',
#   'lender_count': 27},
#  {'id': 1051126,
#   'posted_time': '2016-04-08 00:33:49+00:00',
#   'funded_time': '2016-04-18 01:16:46+00:00',
#   'lender_count': 9},
#  {'id': 848707,
#   'posted_time': '2015-03-01 03:59:59+00:00',
#   'funded_time': '2015-03-06 11:02:07+00:00',
#   'lender_count': 7},
#  {'id': 1233174,
#   'posted_time': '2017-02-07 04:23:39+00:00',
#   'funded_time': '2017-02-23 03:34:28+00:00',
#   'lender_count': 36},
#  {'id': 1127193,
#   'posted_time': '2016-08-01 19:24:05+00:00',
#   'funded_time': '2016-08-17 16:40:09+00:00',
#   'lender_count': 10},
#  {'id': 951045,
#   'posted_time': '2015-09-21 20:07:43+00:00',
#   'funded_time': '2015-10-17 16:08:05+00:00',
#   'lender_count': 13},
#  {'id': 830132,
#   'posted_time': '2015-01-20 08:31:59+00:00',
#   'funded_time': '2015-01-20 23:44:21+00:00',
#   'lender_count': 4},
#  {'id': 1018986,
#   'posted_time': '2016-02-05 11:50:06+00:00',
#   'funded_time': '2016-02-21 15:16:43+00:00',
#   'lender_count': 25},
#  {'id': 1163677,
#   'posted_time': '2016-10-06 08:08:07+00:00',
#   'funded_time': '2016-10-12 22:56:22+00:00',
#   'lender_count': 16},
#  {'id': 1315168,
#   'posted_time': '2017-06-07 06:14:12+00:00',
#   'funded_time': '2017-06-19 10:45:14+00:00',
#   'lender_count': 1},
#  {'id': 1132288,
#   'posted_time': '2016-08-11 23:08:30+00:00',
#   'funded_time': None,
#   'lender_count': 6},
#  {'id': 1237593,
#   'posted_time': '2017-02-14 04:12:34+00:00',
#   'funded_time': '2017-02-18 14:35:17+00:00',
#   'lender_count': 74},
#  {'id': 799201,
#   'posted_time': '2014-11-17 02:05:59+00:00',
#   'funded_time': '2014-11-19 11:47:19+00:00',
#   'lender_count': 8},
#  {'id': 997179,
#   'posted_time': '2015-12-18 08:23:44+00:00',
#   'funded_time': '2015-12-22 14:30:19+00:00',
#   'lender_count': 8},
#  {'id': 661893,
#   'posted_time': '2014-01-26 08:55:06+00:00',
#   'funded_time': '2014-02-24 23:14:33+00:00',
#   'lender_count': 60},
#  {'id': 809496,
#   'posted_time': '2014-12-02 20:56:10+00:00',
#   'funded_time': '2014-12-18 02:45:19+00:00',
#   'lender_count': 122},
#  {'id': 924160,
#   'posted_time': '2015-07-28 07:31:53+00:00',
#   'funded_time': '2015-08-01 16:34:56+00:00',
#   'lender_count': 38},
#  {'id': 769795,
#   'posted_time': '2014-09-17 04:42:05+00:00',
#   'funded_time': '2014-09-21 00:45:47+00:00',
#   'lender_count': 12},
#  {'id': 1022549,
#   'posted_time': '2016-02-15 05:11:08+00:00',
#   'funded_time': '2016-02-17 13:31:20+00:00',
#   'lender_count': 5},
#  {'id': 1179906,
#   'posted_time': '2016-11-04 02:45:07+00:00',
#   'funded_time': '2016-11-13 12:16:27+00:00',
#   'lender_count': 3},
#  {'id': 843657,
#   'posted_time': '2015-02-19 17:53:02+00:00',
#   'funded_time': '2015-03-19 15:30:23+00:00',
#   'lender_count': 20},
#  {'id': 1164224,
#   'posted_time': '2016-10-07 06:42:07+00:00',
#   'funded_time': '2016-11-10 14:55:10+00:00',
#   'lender_count': 24},
#  {'id': 1068413,
#   'posted_time': '2016-05-13 07:22:31+00:00',
#   'funded_time': '2016-05-17 20:00:23+00:00',
#   'lender_count': 9},
#  {'id': 881807,
#   'posted_time': '2015-05-08 02:59:57+00:00',
#   'funded_time': '2015-05-11 04:25:43+00:00',
#   'lender_count': 16},
#  {'id': 1245069,
#   'posted_time': '2017-02-23 18:08:14+00:00',
#   'funded_time': '2017-03-08 13:12:13+00:00',
#   'lender_count': 172},
#  {'id': 1220760,
#   'posted_time': '2017-01-16 08:03:20+00:00',
#   'funded_time': '2017-01-22 19:04:28+00:00',
#   'lender_count': 58},
#  {'id': 726339,
#   'posted_time': '2014-06-17 12:57:55+00:00',
#   'funded_time': '2014-06-22 23:48:47+00:00',
#   'lender_count': 7},
#  {'id': 963481,
#   'posted_time': '2015-10-15 09:05:17+00:00',
#   'funded_time': '2015-10-19 16:37:42+00:00',
#   'lender_count': 8},
#  {'id': 1195704,
#   'posted_time': '2016-11-29 16:16:17+00:00',
#   'funded_time': '2016-12-28 14:47:38+00:00',
#   'lender_count': 10},
#  {'id': 817617,
#   'posted_time': '2014-12-18 16:42:52+00:00',
#   'funded_time': '2014-12-30 22:34:48+00:00',
#   'lender_count': 7},
#  {'id': 1051946,
#   'posted_time': '2016-04-09 17:30:02+00:00',
#   'funded_time': '2016-05-14 19:59:33+00:00',
#   'lender_count': 19},
#  {'id': 855298,
#   'posted_time': '2015-03-13 23:42:17+00:00',
#   'funded_time': '2015-03-19 15:23:27+00:00',
#   'lender_count': 6},
#  {'id': 1114955,
#   'posted_time': '2016-07-12 08:57:06+00:00',
#   'funded_time': '2016-07-19 16:01:49+00:00',
#   'lender_count': 7},
#  {'id': 1171221,
#   'posted_time': '2016-10-20 06:11:58+00:00',
#   'funded_time': '2016-11-25 20:32:31+00:00',
#   'lender_count': 14},
#  {'id': 673505,
#   'posted_time': '2014-02-20 08:28:59+00:00',
#   'funded_time': '2014-02-22 20:30:07+00:00',
#   'lender_count': 5},
#  {'id': 735440,
#   'posted_time': '2014-07-07 08:34:52+00:00',
#   'funded_time': '2014-07-23 23:37:12+00:00',
#   'lender_count': 12},
#  {'id': 664890,
#   'posted_time': '2014-02-03 07:49:05+00:00',
#   'funded_time': '2014-02-27 19:54:12+00:00',
#   'lender_count': 11},
#  {'id': 750861,
#   'posted_time': '2014-08-07 07:29:31+00:00',
#   'funded_time': '2014-08-21 20:04:28+00:00',
#   'lender_count': 9},
#  {'id': 719848,
#   'posted_time': '2014-06-04 06:01:05+00:00',
#   'funded_time': '2014-06-19 03:10:25+00:00',
#   'lender_count': 7},
#  {'id': 976412,
#   'posted_time': '2015-11-10 13:17:12+00:00',
#   'funded_time': '2015-11-24 20:15:30+00:00',
#   'lender_count': 18},
#  {'id': 1245266,
#   'posted_time': '2017-02-24 03:25:03+00:00',
#   'funded_time': '2017-03-01 03:24:18+00:00',
#   'lender_count': 2},
#  {'id': 919307,
#   'posted_time': '2015-07-18 04:13:47+00:00',
#   'funded_time': '2015-07-29 23:18:33+00:00',
#   'lender_count': 46},
#  {'id': 746335,
#   'posted_time': '2014-07-29 11:45:38+00:00',
#   'funded_time': '2014-08-23 19:19:42+00:00',
#   'lender_count': 16},
#  {'id': 935583,
#   'posted_time': '2015-08-20 09:21:56+00:00',
#   'funded_time': '2015-08-23 11:54:09+00:00',
#   'lender_count': 10},
#  {'id': 1039018,
#   'posted_time': '2016-03-15 22:04:52+00:00',
#   'funded_time': '2016-04-13 17:19:13+00:00',
#   'lender_count': 6},
#  {'id': 769581,
#   'posted_time': '2014-09-16 17:59:31+00:00',
#   'funded_time': '2014-10-01 01:24:15+00:00',
#   'lender_count': 77},
#  {'id': 672498,
#   'posted_time': '2014-02-19 05:08:16+00:00',
#   'funded_time': '2014-02-25 15:01:46+00:00',
#   'lender_count': 8},
#  {'id': 807725,
#   'posted_time': '2014-11-28 11:40:19+00:00',
#   'funded_time': '2014-12-12 19:10:00+00:00',
#   'lender_count': 10},
#  {'id': 1252026,
#   'posted_time': '2017-03-07 10:10:35+00:00',
#   'funded_time': '2017-03-28 13:35:34+00:00',
#   'lender_count': 16},
#  {'id': 1254351,
#   'posted_time': '2017-03-10 08:07:01+00:00',
#   'funded_time': '2017-03-14 00:54:07+00:00',
#   'lender_count': 11},
#  {'id': 824800,
#   'posted_time': '2015-01-07 11:53:16+00:00',
#   'funded_time': '2015-01-22 14:49:07+00:00',
#   'lender_count': 14},
#  {'id': 1073183,
#   'posted_time': '2016-05-22 09:40:52+00:00',
#   'funded_time': '2016-05-25 21:42:49+00:00',
#   'lender_count': 6},
#  {'id': 859680,
#   'posted_time': '2015-03-22 13:35:06+00:00',
#   'funded_time': '2015-04-16 12:03:18+00:00',
#   'lender_count': 53},
#  {'id': 662135,
#   'posted_time': '2014-01-27 07:52:54+00:00',
#   'funded_time': '2014-02-25 03:27:30+00:00',
#   'lender_count': 6},
#  {'id': 752110,
#   'posted_time': '2014-08-09 16:20:44+00:00',
#   'funded_time': '2014-08-09 20:41:31+00:00',
#   'lender_count': 3},
#  {'id': 1084098,
#   'posted_time': '2014-10-06 18:44:52+00:00',
#   'funded_time': '2014-11-08 00:09:53+00:00',
#   'lender_count': 118},
#  {'id': 786892,
#   'posted_time': '2014-10-21 22:33:54+00:00',
#   'funded_time': '2014-11-06 21:41:56+00:00',
#   'lender_count': 23},
#  {'id': 1092503,
#   'posted_time': '2016-05-31 15:57:32+00:00',
#   'funded_time': '2016-06-08 21:06:53+00:00',
#   'lender_count': 17},
#  {'id': 1135265,
#   'posted_time': '2016-08-18 17:22:12+00:00',
#   'funded_time': '2016-08-21 17:57:12+00:00',
#   'lender_count': 22},
#  {'id': 1243451,
#   'posted_time': '2017-02-21 16:34:03+00:00',
#   'funded_time': '2017-02-23 03:10:38+00:00',
#   'lender_count': 16},
#  {'id': 1208797,
#   'posted_time': '2016-12-22 06:33:43+00:00',
#   'funded_time': '2016-12-31 10:34:09+00:00',
#   'lender_count': 13},
#  {'id': 860638,
#   'posted_time': '2015-03-24 09:03:45+00:00',
#   'funded_time': '2015-03-30 13:50:04+00:00',
#   'lender_count': 9},
#  {'id': 678426,
#   'posted_time': '2014-03-03 01:00:21+00:00',
#   'funded_time': '2014-03-05 20:54:05+00:00',
#   'lender_count': 32},
#  {'id': 1103527,
#   'posted_time': '2016-06-21 13:49:33+00:00',
#   'funded_time': '2016-06-28 23:33:23+00:00',
#   'lender_count': 15},
#  {'id': 1268118,
#   'posted_time': '2017-03-28 04:52:05+00:00',
#   'funded_time': '2017-04-18 03:45:30+00:00',
#   'lender_count': 7},
#  {'id': 687454,
#   'posted_time': '2014-03-21 21:02:07+00:00',
#   'funded_time': '2014-04-01 17:42:49+00:00',
#   'lender_count': 27},
#  {'id': 1229790,
#   'posted_time': '2017-01-31 08:30:31+00:00',
#   'funded_time': '2017-02-07 13:40:30+00:00',
#   'lender_count': 24},
#  {'id': 964326,
#   'posted_time': '2015-10-16 20:53:27+00:00',
#   'funded_time': '2015-11-22 08:07:18+00:00',
#   'lender_count': 179},
#  {'id': 1265363,
#   'posted_time': '2017-03-23 19:20:57+00:00',
#   'funded_time': '2017-04-02 08:04:43+00:00',
#   'lender_count': 14},
#  {'id': 1292856,
#   'posted_time': '2017-05-05 01:31:38+00:00',
#   'funded_time': '2017-05-10 23:17:11+00:00',
#   'lender_count': 1},
#  {'id': 1186270,
#   'posted_time': '2016-11-17 00:40:37+00:00',
#   'funded_time': '2016-11-21 18:39:09+00:00',
#   'lender_count': 11},
#  {'id': 783507,
#   'posted_time': '2014-10-15 11:44:21+00:00',
#   'funded_time': '2014-10-22 12:26:30+00:00',
#   'lender_count': 37},
#  {'id': 1020406,
#   'posted_time': '2016-02-10 01:36:39+00:00',
#   'funded_time': '2016-03-08 18:01:44+00:00',
#   'lender_count': 32},
#  {'id': 1255831,
#   'posted_time': '2017-03-13 08:35:09+00:00',
#   'funded_time': '2017-03-15 16:10:08+00:00',
#   'lender_count': 7},
#  {'id': 685507,
#   'posted_time': '2014-03-18 15:53:37+00:00',
#   'funded_time': '2014-04-16 15:48:34+00:00',
#   'lender_count': 23},
#  {'id': 701805,
#   'posted_time': '2014-04-24 07:13:34+00:00',
#   'funded_time': '2014-07-10 20:21:22+00:00',
#   'lender_count': 54},
#  {'id': 848788,
#   'posted_time': '2015-03-01 10:52:15+00:00',
#   'funded_time': '2015-03-11 19:01:53+00:00',
#   'lender_count': 12},
#  {'id': 991890,
#   'posted_time': '2015-12-08 23:15:26+00:00',
#   'funded_time': '2015-12-17 20:03:56+00:00',
#   'lender_count': 28},
#  {'id': 774647,
#   'posted_time': '2014-09-25 09:12:13+00:00',
#   'funded_time': '2014-10-05 13:02:43+00:00',
#   'lender_count': 19},
#  {'id': 822583,
#   'posted_time': '2014-12-30 15:37:24+00:00',
#   'funded_time': '2014-12-31 13:25:21+00:00',
#   'lender_count': 16},
#  {'id': 1179766,
#   'posted_time': '2016-11-03 21:47:09+00:00',
#   'funded_time': '2016-11-16 07:11:15+00:00',
#   'lender_count': 77},
#  {'id': 1207474,
#   'posted_time': '2016-12-21 01:24:12+00:00',
#   'funded_time': '2016-12-24 01:35:00+00:00',
#   'lender_count': 2},
#  {'id': 1286420,
#   'posted_time': '2017-04-26 07:12:42+00:00',
#   'funded_time': '2017-05-03 03:20:08+00:00',
#   'lender_count': 4},
#  {'id': 1032238,
#   'posted_time': '2016-03-02 11:30:40+00:00',
#   'funded_time': '2016-03-24 22:26:57+00:00',
#   'lender_count': 19},
#  {'id': 668815,
#   'posted_time': '2014-02-12 10:25:03+00:00',
#   'funded_time': '2014-02-12 18:24:09+00:00',
#   'lender_count': 19},
#  {'id': 936084,
#   'posted_time': '2015-08-21 04:22:46+00:00',
#   'funded_time': '2015-09-20 07:11:30+00:00',
#   'lender_count': 8},
#  {'id': 1106370,
#   'posted_time': '2016-06-26 18:57:42+00:00',
#   'funded_time': '2016-07-02 02:20:23+00:00',
#   'lender_count': 17},
#  {'id': 1292386,
#   'posted_time': '2017-05-04 08:22:05+00:00',
#   'funded_time': '2017-05-10 09:10:37+00:00',
#   'lender_count': 2},
#  {'id': 1265655,
#   'posted_time': '2017-03-24 04:32:33+00:00',
#   'funded_time': '2017-04-04 00:49:51+00:00',
#   'lender_count': 16},
#  {'id': 1054619,
#   'posted_time': '2016-04-15 00:36:42+00:00',
#   'funded_time': '2016-04-20 06:03:07+00:00',
#   'lender_count': 38},
#  {'id': 874928,
#   'posted_time': '2015-04-23 15:42:56+00:00',
#   'funded_time': None,
#   'lender_count': 130},
#  {'id': 893750,
#   'posted_time': '2015-05-28 16:17:14+00:00',
#   'funded_time': '2015-06-15 20:59:04+00:00',
#   'lender_count': 50},
#  {'id': 793723,
#   'posted_time': '2014-11-04 10:06:40+00:00',
#   'funded_time': '2014-11-17 15:23:45+00:00',
#   'lender_count': 49},
#  {'id': 826748,
#   'posted_time': '2015-01-12 03:44:35+00:00',
#   'funded_time': '2015-01-18 16:15:16+00:00',
#   'lender_count': 8},
#  {'id': 771541,
#   'posted_time': '2014-09-19 04:10:42+00:00',
#   'funded_time': '2014-10-23 07:47:59+00:00',
#   'lender_count': 26},
#  {'id': 765368,
#   'posted_time': '2014-09-08 12:26:57+00:00',
#   'funded_time': '2014-09-11 20:54:34+00:00',
#   'lender_count': 39},
#  {'id': 1211280,
#   'posted_time': '2016-12-27 16:18:40+00:00',
#   'funded_time': '2017-01-26 16:52:28+00:00',
#   'lender_count': 21},
#  {'id': 934961,
#   'posted_time': '2015-08-19 12:38:43+00:00',
#   'funded_time': '2015-09-21 03:41:30+00:00',
#   'lender_count': 13},
#  {'id': 790938,
#   'posted_time': '2014-10-29 09:52:06+00:00',
#   'funded_time': '2014-11-24 01:20:58+00:00',
#   'lender_count': 35},
#  {'id': 1275044,
#   'posted_time': '2017-04-06 17:42:11+00:00',
#   'funded_time': '2017-04-17 14:15:30+00:00',
#   'lender_count': 3},
#  {'id': 896450,
#   'posted_time': '2015-06-03 16:24:04+00:00',
#   'funded_time': '2015-06-23 17:34:45+00:00',
#   'lender_count': 12},
#  {'id': 1216917,
#   'posted_time': '2017-01-07 11:56:25+00:00',
#   'funded_time': '2017-01-15 18:48:46+00:00',
#   'lender_count': 14},
#  {'id': 1273844,
#   'posted_time': '2017-04-05 09:24:08+00:00',
#   'funded_time': '2017-04-13 04:07:27+00:00',
#   'lender_count': 3},
#  {'id': 1119544,
#   'posted_time': '2016-07-20 07:10:31+00:00',
#   'funded_time': '2016-08-10 16:53:51+00:00',
#   'lender_count': 8},
#  {'id': 936657,
#   'posted_time': '2015-08-21 20:20:14+00:00',
#   'funded_time': None,
#   'lender_count': 24},
#  {'id': 1122617,
#   'posted_time': '2016-07-25 08:25:16+00:00',
#   'funded_time': '2016-08-03 01:05:39+00:00',
#   'lender_count': 4},
#  {'id': 910183,
#   'posted_time': '2015-06-29 09:47:16+00:00',
#   'funded_time': '2015-07-30 15:07:23+00:00',
#   'lender_count': 38},
#  {'id': 902205,
#   'posted_time': '2015-06-16 03:42:34+00:00',
#   'funded_time': '2015-06-18 21:26:36+00:00',
#   'lender_count': 5},
#  {'id': 1143042,
#   'posted_time': '2016-08-31 10:00:14+00:00',
#   'funded_time': None,
#   'lender_count': 24},
#  {'id': 674213,
#   'posted_time': '2014-02-21 05:58:17+00:00',
#   'funded_time': '2014-02-24 00:36:31+00:00',
#   'lender_count': 8},
#  {'id': 911552,
#   'posted_time': '2015-07-01 22:53:55+00:00',
#   'funded_time': '2015-07-22 01:16:14+00:00',
#   'lender_count': 7},
#  {'id': 949841,
#   'posted_time': '2015-09-18 20:20:19+00:00',
#   'funded_time': '2015-10-22 13:40:21+00:00',
#   'lender_count': 21},
#  {'id': 913452,
#   'posted_time': '2015-07-06 07:10:42+00:00',
#   'funded_time': '2015-07-28 02:19:06+00:00',
#   'lender_count': 23},
#  {'id': 973214,
#   'posted_time': '2015-11-04 04:57:11+00:00',
#   'funded_time': '2015-12-01 16:26:04+00:00',
#   'lender_count': 13},
#  {'id': 968246,
#   'posted_time': '2015-10-23 15:33:02+00:00',
#   'funded_time': '2015-11-20 18:55:55+00:00',
#   'lender_count': 6},
#  {'id': 1178622,
#   'posted_time': '2016-11-02 07:00:12+00:00',
#   'funded_time': '2016-11-18 23:53:43+00:00',
#   'lender_count': 8},
#  {'id': 1032448,
#   'posted_time': '2016-03-03 01:10:20+00:00',
#   'funded_time': '2016-03-06 17:30:42+00:00',
#   'lender_count': 5},
#  {'id': 1272894,
#   'posted_time': '2017-04-04 07:32:47+00:00',
#   'funded_time': '2017-05-08 01:05:42+00:00',
#   'lender_count': 77},
#  {'id': 699717,
#   'posted_time': '2014-04-20 11:21:29+00:00',
#   'funded_time': '2014-05-13 18:31:09+00:00',
#   'lender_count': 13},
#  {'id': 740033,
#   'posted_time': '2014-07-17 01:12:40+00:00',
#   'funded_time': '2014-07-21 18:41:49+00:00',
#   'lender_count': 2},
#  {'id': 963510,
#   'posted_time': '2015-10-15 09:49:52+00:00',
#   'funded_time': '2015-10-22 01:12:17+00:00',
#   'lender_count': 22},
#  {'id': 1116982,
#   'posted_time': '2016-07-15 11:07:56+00:00',
#   'funded_time': '2016-08-22 17:24:03+00:00',
#   'lender_count': 12},
#  {'id': 711904,
#   'posted_time': '2014-05-19 09:06:47+00:00',
#   'funded_time': '2014-05-21 23:04:44+00:00',
#   'lender_count': 12},
#  {'id': 1094663,
#   'posted_time': '2016-06-03 11:21:10+00:00',
#   'funded_time': '2016-06-15 17:52:39+00:00',
#   'lender_count': 55},
#  {'id': 1262844,
#   'posted_time': '2017-03-21 12:22:02+00:00',
#   'funded_time': '2017-03-26 20:18:24+00:00',
#   'lender_count': 8},
#  {'id': 1020866,
#   'posted_time': '2016-02-10 12:38:20+00:00',
#   'funded_time': '2016-02-19 16:57:53+00:00',
#   'lender_count': 20},
#  {'id': 902363,
#   'posted_time': '2015-06-16 06:48:11+00:00',
#   'funded_time': '2015-06-19 01:55:57+00:00',
#   'lender_count': 6},
#  {'id': 1249083,
#   'posted_time': '2017-03-02 05:01:20+00:00',
#   'funded_time': '2017-03-08 15:55:27+00:00',
#   'lender_count': 8},
#  {'id': 1097532,
#   'posted_time': '2016-06-10 04:15:56+00:00',
#   'funded_time': None,
#   'lender_count': 6},
#  {'id': 978445,
#   'posted_time': '2015-11-13 15:23:01+00:00',
#   'funded_time': '2015-11-23 04:29:51+00:00',
#   'lender_count': 11},
#  {'id': 945738,
#   'posted_time': '2015-09-10 11:29:16+00:00',
#   'funded_time': '2015-10-08 20:03:04+00:00',
#   'lender_count': 12},
#  {'id': 1127153,
#   'posted_time': '2016-08-01 17:29:30+00:00',
#   'funded_time': '2016-09-14 12:27:03+00:00',
#   'lender_count': 22},
#  {'id': 1057476,
#   'posted_time': '2016-04-20 14:48:13+00:00',
#   'funded_time': '2016-04-25 13:24:40+00:00',
#   'lender_count': 5},
#  {'id': 1034866,
#   'posted_time': '2016-03-08 02:42:27+00:00',
#   'funded_time': '2016-03-08 11:33:11+00:00',
#   'lender_count': 1},
#  {'id': 782906,
#   'posted_time': '2014-10-14 13:49:59+00:00',
#   'funded_time': '2014-10-18 17:32:38+00:00',
#   'lender_count': 11},
#  {'id': 1131816,
#   'posted_time': '2016-08-11 06:41:26+00:00',
#   'funded_time': '2016-09-17 16:26:41+00:00',
#   'lender_count': 9},
#  {'id': 807010,
#   'posted_time': '2014-11-27 13:32:58+00:00',
#   'funded_time': None,
#   'lender_count': 7},
#  {'id': 693461,
#   'posted_time': '2014-04-04 08:06:32+00:00',
#   'funded_time': '2014-04-06 19:23:56+00:00',
#   'lender_count': 9},
#  {'id': 919951,
#   'posted_time': '2015-07-20 12:30:39+00:00',
#   'funded_time': '2015-08-02 20:53:32+00:00',
#   'lender_count': 9},
#  {'id': 1131093,
#   'posted_time': '2016-08-10 04:49:07+00:00',
#   'funded_time': '2016-08-19 01:59:34+00:00',
#   'lender_count': 6},
#  {'id': 1050995,
#   'posted_time': '2016-04-07 17:20:38+00:00',
#   'funded_time': '2016-04-12 03:50:45+00:00',
#   'lender_count': 13},
#  {'id': 1280700,
#   'posted_time': '2017-04-18 07:40:19+00:00',
#   'funded_time': '2017-05-05 20:55:20+00:00',
#   'lender_count': 1},
#  {'id': 1336033,
#   'posted_time': '2017-07-07 17:20:30+00:00',
#   'funded_time': None,
#   'lender_count': 3},
#  {'id': 1214426,
#   'posted_time': '2017-01-03 09:34:56+00:00',
#   'funded_time': '2017-01-03 20:50:18+00:00',
#   'lender_count': 7},
#  {'id': 1153151,
#   'posted_time': '2016-09-19 20:28:10+00:00',
#   'funded_time': '2016-09-26 16:01:30+00:00',
#   'lender_count': 13},
#  {'id': 867100,
#   'posted_time': '2015-04-08 06:54:55+00:00',
#   'funded_time': '2015-05-12 16:49:32+00:00',
#   'lender_count': 23},
#  {'id': 1082211,
#   'posted_time': '2014-07-20 06:21:35+00:00',
#   'funded_time': '2014-07-24 14:34:06+00:00',
#   'lender_count': 7},
#  {'id': 844414,
#   'posted_time': '2015-02-20 20:27:11+00:00',
#   'funded_time': '2015-03-23 18:28:21+00:00',
#   'lender_count': 47},
#  {'id': 1090252,
#   'posted_time': '2015-09-29 00:51:09+00:00',
#   'funded_time': '2015-10-17 04:44:45+00:00',
#   'lender_count': 55},
#  {'id': 692371,
#   'posted_time': '2014-04-02 10:59:03+00:00',
#   'funded_time': '2014-04-05 20:36:12+00:00',
#   'lender_count': 12},
#  {'id': 1048653,
#   'posted_time': '2016-04-03 14:34:02+00:00',
#   'funded_time': '2016-05-09 17:06:49+00:00',
#   'lender_count': 9},
#  {'id': 1112848,
#   'posted_time': '2016-07-07 16:15:11+00:00',
#   'funded_time': '2016-07-19 23:12:17+00:00',
#   'lender_count': 5},
#  {'id': 924616,
#   'posted_time': '2015-07-28 21:07:01+00:00',
#   'funded_time': None,
#   'lender_count': 9},
#  {'id': 1048781,
#   'posted_time': '2016-04-04 05:05:45+00:00',
#   'funded_time': '2016-04-22 10:44:24+00:00',
#   'lender_count': 8},
#  {'id': 1193864,
#   'posted_time': '2016-11-27 02:43:19+00:00',
#   'funded_time': '2016-12-08 15:08:50+00:00',
#   'lender_count': 9},
#  {'id': 1228184,
#   'posted_time': '2017-01-27 09:10:42+00:00',
#   'funded_time': '2017-01-28 20:04:18+00:00',
#   'lender_count': 3},
#  {'id': 777401,
#   'posted_time': '2014-10-01 06:24:18+00:00',
#   'funded_time': '2014-10-14 20:51:18+00:00',
#   'lender_count': 35},
#  {'id': 921081,
#   'posted_time': '2015-07-22 05:12:56+00:00',
#   'funded_time': '2015-08-05 21:35:09+00:00',
#   'lender_count': 49},
#  {'id': 960432,
#   'posted_time': '2015-10-09 06:12:59+00:00',
#   'funded_time': '2015-10-28 19:53:04+00:00',
#   'lender_count': 9},
#  {'id': 872470,
#   'posted_time': '2015-04-20 16:02:14+00:00',
#   'funded_time': '2015-05-08 04:56:58+00:00',
#   'lender_count': 30},
#  {'id': 895772,
#   'posted_time': '2015-06-02 15:01:28+00:00',
#   'funded_time': '2015-06-10 16:33:59+00:00',
#   'lender_count': 11},
#  {'id': 1226834,
#   'posted_time': '2017-01-25 09:37:26+00:00',
#   'funded_time': '2017-01-28 19:02:11+00:00',
#   'lender_count': 4},
#  {'id': 1289317,
#   'posted_time': '2017-04-29 04:52:00+00:00',
#   'funded_time': '2017-05-27 09:19:21+00:00',
#   'lender_count': 24},
#  {'id': 768217,
#   'posted_time': '2014-09-14 10:23:01+00:00',
#   'funded_time': '2014-09-19 00:40:11+00:00',
#   'lender_count': 20},
#  {'id': 1229489,
#   'posted_time': '2017-01-31 03:17:50+00:00',
#   'funded_time': '2017-01-31 03:44:47+00:00',
#   'lender_count': 1},
#  {'id': 1223938,
#   'posted_time': '2017-01-20 14:28:23+00:00',
#   'funded_time': '2017-02-17 18:42:44+00:00',
#   'lender_count': 48},
#  {'id': 910992,
#   'posted_time': '2015-06-30 21:30:23+00:00',
#   'funded_time': None,
#   'lender_count': 13},
#  {'id': 870027,
#   'posted_time': '2015-04-15 03:57:40+00:00',
#   'funded_time': '2015-05-21 21:39:56+00:00',
#   'lender_count': 38},
#  {'id': 1308069,
#   'posted_time': '2017-05-26 20:53:26+00:00',
#   'funded_time': '2017-06-28 21:23:24+00:00',
#   'lender_count': 11},
#  {'id': 1016773,
#   'posted_time': '2016-02-01 11:11:30+00:00',
#   'funded_time': '2016-03-02 16:38:41+00:00',
#   'lender_count': 20},
#  {'id': 955750,
#   'posted_time': '2015-09-30 13:03:20+00:00',
#   'funded_time': None,
#   'lender_count': 22},
#  {'id': 707615,
#   'posted_time': '2014-05-08 15:46:31+00:00',
#   'funded_time': '2014-05-24 15:33:18+00:00',
#   'lender_count': 37},
#  {'id': 808335,
#   'posted_time': '2014-12-01 01:11:01+00:00',
#   'funded_time': '2014-12-06 00:01:45+00:00',
#   'lender_count': 1},
#  {'id': 680224,
#   'posted_time': '2014-03-06 11:35:15+00:00',
#   'funded_time': '2014-03-09 08:12:44+00:00',
#   'lender_count': 5},
#  {'id': 960022,
#   'posted_time': '2015-10-08 14:45:46+00:00',
#   'funded_time': '2015-11-13 09:00:53+00:00',
#   'lender_count': 15},
#  {'id': 843688,
#   'posted_time': '2015-02-19 19:39:19+00:00',
#   'funded_time': '2015-03-23 04:46:30+00:00',
#   'lender_count': 35},
#  {'id': 653313,
#   'posted_time': '2014-01-02 12:23:38+00:00',
#   'funded_time': '2014-01-16 20:40:51+00:00',
#   'lender_count': 22},
#  {'id': 855864,
#   'posted_time': '2015-03-16 10:49:26+00:00',
#   'funded_time': '2015-03-24 11:59:02+00:00',
#   'lender_count': 9},
#  {'id': 897509,
#   'posted_time': '2015-06-05 09:49:08+00:00',
#   'funded_time': None,
#   'lender_count': 23},
#  {'id': 846759,
#   'posted_time': '2015-02-25 14:51:34+00:00',
#   'funded_time': '2015-03-21 19:03:12+00:00',
#   'lender_count': 30},
#  {'id': 1114126,
#   'posted_time': '2016-07-11 05:59:28+00:00',
#   'funded_time': '2016-07-17 22:18:19+00:00',
#   'lender_count': 5},
#  {'id': 667269,
#   'posted_time': '2014-02-10 02:22:18+00:00',
#   'funded_time': '2014-02-26 22:17:18+00:00',
#   'lender_count': 9},
#  {'id': 848694,
#   'posted_time': '2015-03-01 02:11:03+00:00',
#   'funded_time': '2015-03-22 16:33:50+00:00',
#   'lender_count': 23},
#  {'id': 924169,
#   'posted_time': '2015-07-28 07:46:12+00:00',
#   'funded_time': '2015-08-13 17:42:23+00:00',
#   'lender_count': 20},
#  {'id': 1072798,
#   'posted_time': '2016-05-20 21:40:03+00:00',
#   'funded_time': '2016-05-25 12:45:51+00:00',
#   'lender_count': 4},
#  {'id': 1087649,
#   'posted_time': '2015-02-23 11:32:08+00:00',
#   'funded_time': '2015-03-18 06:46:14+00:00',
#   'lender_count': 18},
#  {'id': 1219100,
#   'posted_time': '2017-01-12 06:59:29+00:00',
#   'funded_time': '2017-02-21 13:42:38+00:00',
#   'lender_count': 14},
#  {'id': 1101103,
#   'posted_time': '2016-06-17 07:03:14+00:00',
#   'funded_time': '2016-07-21 22:32:19+00:00',
#   'lender_count': 13},
#  {'id': 665399,
#   'posted_time': '2014-02-04 11:41:08+00:00',
#   'funded_time': '2014-02-25 22:20:56+00:00',
#   'lender_count': 74},
#  {'id': 831040,
#   'posted_time': '2015-01-22 06:57:24+00:00',
#   'funded_time': '2015-01-29 05:18:27+00:00',
#   'lender_count': 17},
#  {'id': 997318,
#   'posted_time': '2015-12-18 12:14:15+00:00',
#   'funded_time': '2016-01-21 02:29:51+00:00',
#   'lender_count': 73},
#  {'id': 831813,
#   'posted_time': '2015-01-23 12:10:31+00:00',
#   'funded_time': '2015-01-28 23:27:51+00:00',
#   'lender_count': 14},
#  {'id': 1298256,
#   'posted_time': '2017-05-15 02:23:18+00:00',
#   'funded_time': '2017-05-21 01:14:33+00:00',
#   'lender_count': 1},
#  {'id': 1147712,
#   'posted_time': '2016-09-08 14:23:14+00:00',
#   'funded_time': '2016-10-09 08:01:52+00:00',
#   'lender_count': 35},
#  {'id': 774352,
#   'posted_time': '2014-09-24 21:17:01+00:00',
#   'funded_time': '2014-10-17 19:22:30+00:00',
#   'lender_count': 81},
#  {'id': 778373,
#   'posted_time': '2014-10-03 02:11:02+00:00',
#   'funded_time': '2014-10-06 18:36:29+00:00',
#   'lender_count': 1},
#  {'id': 850145,
#   'posted_time': '2015-03-04 06:03:10+00:00',
#   'funded_time': '2015-03-10 23:03:47+00:00',
#   'lender_count': 5},
#  {'id': 781619,
#   'posted_time': '2014-10-11 07:37:49+00:00',
#   'funded_time': '2014-10-16 01:18:20+00:00',
#   'lender_count': 9},
#  {'id': 1315948,
#   'posted_time': '2017-06-08 03:25:53+00:00',
#   'funded_time': '2017-06-21 21:32:38+00:00',
#   'lender_count': 10},
#  {'id': 927282,
#   'posted_time': '2015-08-03 21:20:34+00:00',
#   'funded_time': '2015-08-06 14:16:33+00:00',
#   'lender_count': 41},
#  {'id': 677505,
#   'posted_time': '2014-02-27 08:53:43+00:00',
#   'funded_time': '2014-03-13 01:41:12+00:00',
#   'lender_count': 22},
#  {'id': 735304,
#   'posted_time': '2014-07-06 20:30:50+00:00',
#   'funded_time': '2014-07-17 18:53:19+00:00',
#   'lender_count': 22},
#  {'id': 987615,
#   'posted_time': '2015-11-30 08:44:45+00:00',
#   'funded_time': '2015-12-01 20:11:35+00:00',
#   'lender_count': 8},
#  {'id': 972053,
#   'posted_time': '2015-10-31 16:32:08+00:00',
#   'funded_time': '2015-12-09 14:55:55+00:00',
#   'lender_count': 27},
#  {'id': 696856,
#   'posted_time': '2014-04-11 13:26:00+00:00',
#   'funded_time': '2014-04-15 18:26:27+00:00',
#   'lender_count': 14},
#  {'id': 1290688,
#   'posted_time': '2017-05-02 13:50:30+00:00',
#   'funded_time': '2017-05-17 15:23:57+00:00',
#   'lender_count': 10},
#  {'id': 1225177,
#   'posted_time': '2017-01-23 12:03:56+00:00',
#   'funded_time': '2017-02-18 23:09:16+00:00',
#   'lender_count': 9},
#  {'id': 1290196,
#   'posted_time': '2017-05-02 03:24:22+00:00',
#   'funded_time': '2017-05-07 13:52:38+00:00',
#   'lender_count': 4},
#  {'id': 1237869,
#   'posted_time': '2017-02-14 07:10:10+00:00',
#   'funded_time': '2017-02-18 23:03:47+00:00',
#   'lender_count': 4},
#  {'id': 791504,
#   'posted_time': '2014-10-30 06:41:19+00:00',
#   'funded_time': '2014-11-06 01:32:21+00:00',
#   'lender_count': 11},
#  {'id': 1229286,
#   'posted_time': '2017-01-30 17:30:52+00:00',
#   'funded_time': '2017-02-17 17:16:19+00:00',
#   'lender_count': 20},
#  {'id': 777125,
#   'posted_time': '2014-09-30 17:32:08+00:00',
#   'funded_time': None,
#   'lender_count': 13},
#  {'id': 755551,
#   'posted_time': '2014-08-18 03:53:42+00:00',
#   'funded_time': '2014-08-26 03:11:58+00:00',
#   'lender_count': 8},
#  {'id': 689928,
#   'posted_time': '2014-03-27 10:57:13+00:00',
#   'funded_time': '2014-04-23 11:53:12+00:00',
#   'lender_count': 21},
#  {'id': 775622,
#   'posted_time': '2014-09-26 16:36:09+00:00',
#   'funded_time': '2014-10-06 14:46:36+00:00',
#   'lender_count': 14},
#  {'id': 886285,
#   'posted_time': '2015-05-15 16:03:51+00:00',
#   'funded_time': '2015-05-26 19:53:02+00:00',
#   'lender_count': 39},
#  {'id': 752852,
#   'posted_time': '2014-08-12 03:55:36+00:00',
#   'funded_time': '2014-08-19 02:43:43+00:00',
#   'lender_count': 35},
#  {'id': 1286784,
#   'posted_time': '2017-04-26 11:30:50+00:00',
#   'funded_time': '2017-05-06 12:43:58+00:00',
#   'lender_count': 8},
#  {'id': 991606,
#   'posted_time': '2015-12-08 09:05:18+00:00',
#   'funded_time': '2016-01-01 12:20:30+00:00',
#   'lender_count': 30},
#  {'id': 887414,
#   'posted_time': '2015-05-19 00:57:05+00:00',
#   'funded_time': '2015-06-04 13:03:32+00:00',
#   'lender_count': 44},
#  {'id': 981717,
#   'posted_time': '2015-11-19 21:46:58+00:00',
#   'funded_time': '2015-11-24 17:51:08+00:00',
#   'lender_count': 2},
#  {'id': 723198,
#   'posted_time': '2014-06-11 08:51:56+00:00',
#   'funded_time': '2014-06-17 18:01:26+00:00',
#   'lender_count': 22},
#  {'id': 1125467,
#   'posted_time': '2016-07-28 15:48:45+00:00',
#   'funded_time': '2016-09-01 06:24:08+00:00',
#   'lender_count': 43},
#  {'id': 1176271,
#   'posted_time': '2016-10-27 20:31:52+00:00',
#   'funded_time': '2016-11-08 18:28:01+00:00',
#   'lender_count': 11},
#  {'id': 1207023,
#   'posted_time': '2016-12-20 10:48:45+00:00',
#   'funded_time': '2016-12-24 03:07:32+00:00',
#   'lender_count': 9},
#  {'id': 998474,
#   'posted_time': '2015-12-21 15:19:31+00:00',
#   'funded_time': None,
#   'lender_count': 36},
#  {'id': 1206828,
#   'posted_time': '2016-12-20 08:17:08+00:00',
#   'funded_time': '2016-12-31 17:23:53+00:00',
#   'lender_count': 21},
#  {'id': 710531,
#   'posted_time': '2014-05-15 09:48:21+00:00',
#   'funded_time': '2014-06-17 12:47:40+00:00',
#   'lender_count': 17},
#  {'id': 1030554,
#   'posted_time': '2016-02-29 05:37:12+00:00',
#   'funded_time': '2016-03-05 01:28:35+00:00',
#   'lender_count': 1},
#  {'id': 930465,
#   'posted_time': '2015-08-11 09:11:53+00:00',
#   'funded_time': '2015-09-09 17:42:52+00:00',
#   'lender_count': 31},
#  {'id': 1334604,
#   'posted_time': '2017-07-06 05:26:38+00:00',
#   'funded_time': '2017-07-14 16:20:24+00:00',
#   'lender_count': 11},
#  {'id': 817262,
#   'posted_time': '2014-12-18 08:38:09+00:00',
#   'funded_time': '2015-01-19 18:48:29+00:00',
#   'lender_count': 16},
#  {'id': 859945,
#   'posted_time': '2015-03-23 08:02:34+00:00',
#   'funded_time': '2015-04-23 03:11:36+00:00',
#   'lender_count': 26},
#  {'id': 888492,
#   'posted_time': '2015-05-20 08:46:20+00:00',
#   'funded_time': '2015-05-23 01:23:05+00:00',
#   'lender_count': 9},
#  {'id': 776465,
#   'posted_time': '2014-09-29 15:56:19+00:00',
#   'funded_time': '2014-10-31 01:02:54+00:00',
#   'lender_count': 39},
#  {'id': 784046,
#   'posted_time': '2014-10-16 08:17:39+00:00',
#   'funded_time': '2014-10-29 16:10:56+00:00',
#   'lender_count': 19},
#  {'id': 1039952,
#   'posted_time': '2016-03-17 04:43:59+00:00',
#   'funded_time': '2016-03-27 06:47:55+00:00',
#   'lender_count': 7},
#  {'id': 977419,
#   'posted_time': '2015-11-12 04:31:59+00:00',
#   'funded_time': '2015-11-25 06:53:26+00:00',
#   'lender_count': 18},
#  {'id': 1214499,
#   'posted_time': '2017-01-03 12:29:40+00:00',
#   'funded_time': '2017-01-29 09:33:21+00:00',
#   'lender_count': 25},
#  {'id': 903437,
#   'posted_time': '2015-06-17 16:00:53+00:00',
#   'funded_time': '2015-07-27 18:59:23+00:00',
#   'lender_count': 57},
#  {'id': 730226,
#   'posted_time': '2014-06-24 21:13:19+00:00',
#   'funded_time': '2014-07-01 07:28:48+00:00',
#   'lender_count': 6},
#  {'id': 1167776,
#   'posted_time': '2016-10-14 02:44:50+00:00',
#   'funded_time': '2016-10-22 00:31:11+00:00',
#   'lender_count': 19},
#  {'id': 1019125,
#   'posted_time': '2016-02-06 04:32:24+00:00',
#   'funded_time': '2016-02-22 09:04:33+00:00',
#   'lender_count': 24},
#  {'id': 676554,
#   'posted_time': '2014-02-25 21:42:02+00:00',
#   'funded_time': '2014-04-01 02:07:56+00:00',
#   'lender_count': 29},
#  {'id': 666346,
#   'posted_time': '2014-02-06 15:28:40+00:00',
#   'funded_time': '2014-02-21 01:23:07+00:00',
#   'lender_count': 15},
#  {'id': 856040,
#   'posted_time': '2015-03-16 15:56:12+00:00',
#   'funded_time': '2015-03-20 21:26:03+00:00',
#   'lender_count': 5},
#  {'id': 772077,
#   'posted_time': '2014-09-20 00:34:34+00:00',
#   'funded_time': '2014-09-25 20:17:48+00:00',
#   'lender_count': 7},
#  {'id': 1304481,
#   'posted_time': '2017-05-23 11:18:37+00:00',
#   'funded_time': '2017-06-23 19:02:46+00:00',
#   'lender_count': 4},
#  {'id': 771937,
#   'posted_time': '2014-09-19 15:47:05+00:00',
#   'funded_time': '2014-09-30 08:16:25+00:00',
#   'lender_count': 48},
#  {'id': 1112876,
#   'posted_time': '2016-07-07 16:45:05+00:00',
#   'funded_time': '2016-07-19 17:32:11+00:00',
#   'lender_count': 25},
#  {'id': 1002571,
#   'posted_time': '2015-12-30 22:19:28+00:00',
#   'funded_time': '2016-01-01 05:56:10+00:00',
#   'lender_count': 20},
#  {'id': 1029580,
#   'posted_time': '2016-02-26 07:23:52+00:00',
#   'funded_time': '2016-03-03 21:46:27+00:00',
#   'lender_count': 3},
#  {'id': 782473,
#   'posted_time': '2014-10-13 22:08:01+00:00',
#   'funded_time': '2014-10-29 19:53:01+00:00',
#   'lender_count': 9},
#  {'id': 1326535,
#   'posted_time': '2017-06-23 07:57:07+00:00',
#   'funded_time': None,
#   'lender_count': 3},
#  {'id': 1209870,
#   'posted_time': '2016-12-23 14:40:43+00:00',
#   'funded_time': '2017-01-17 18:53:44+00:00',
#   'lender_count': 10},
#  {'id': 951760,
#   'posted_time': '2015-09-22 12:44:20+00:00',
#   'funded_time': '2015-10-05 16:09:40+00:00',
#   'lender_count': 5},
#  {'id': 928925,
#   'posted_time': '2015-08-06 19:42:45+00:00',
#   'funded_time': '2015-09-10 03:10:53+00:00',
#   'lender_count': 11},
#  {'id': 932092,
#   'posted_time': '2015-08-14 03:03:24+00:00',
#   'funded_time': '2015-09-10 06:39:46+00:00',
#   'lender_count': 45},
#  {'id': 1276256,
#   'posted_time': '2017-04-10 01:31:24+00:00',
#   'funded_time': '2017-04-17 16:32:24+00:00',
#   'lender_count': 8},
#  {'id': 1251606,
#   'posted_time': '2017-03-07 00:40:03+00:00',
#   'funded_time': '2017-03-07 02:23:15+00:00',
#   'lender_count': 7},
#  {'id': 797004,
#   'posted_time': '2014-11-12 03:56:40+00:00',
#   'funded_time': '2014-12-15 01:04:02+00:00',
#   'lender_count': 12},
#  {'id': 1093903,
#   'posted_time': '2016-06-02 12:10:41+00:00',
#   'funded_time': None,
#   'lender_count': 11},
#  {'id': 962302,
#   'posted_time': '2015-10-13 12:58:28+00:00',
#   'funded_time': None,
#   'lender_count': 16},
#  {'id': 843182,
#   'posted_time': '2015-02-19 05:17:47+00:00',
#   'funded_time': '2015-02-22 23:38:03+00:00',
#   'lender_count': 9},
#  {'id': 1240470,
#   'posted_time': '2017-02-17 06:02:26+00:00',
#   'funded_time': '2017-02-23 17:09:12+00:00',
#   'lender_count': 3},
#  {'id': 875183,
#   'posted_time': '2015-04-24 03:45:13+00:00',
#   'funded_time': '2015-05-30 06:28:42+00:00',
#   'lender_count': 55},
#  {'id': 891380,
#   'posted_time': '2015-05-25 15:38:34+00:00',
#   'funded_time': '2015-05-31 22:13:02+00:00',
#   'lender_count': 10},
#  {'id': 1255081,
#   'posted_time': '2017-03-11 14:16:07+00:00',
#   'funded_time': '2017-03-18 02:09:11+00:00',
#   'lender_count': 13},
#  {'id': 1092477,
#   'posted_time': '2016-05-31 15:28:38+00:00',
#   'funded_time': None,
#   'lender_count': 11},
#  {'id': 1040273,
#   'posted_time': '2016-03-17 11:11:07+00:00',
#   'funded_time': '2016-03-26 18:29:00+00:00',
#   'lender_count': 3},
#  {'id': 1296919,
#   'posted_time': '2017-05-12 06:31:27+00:00',
#   'funded_time': '2017-05-18 11:25:39+00:00',
#   'lender_count': 2},
#  {'id': 828301,
#   'posted_time': '2015-01-15 08:56:35+00:00',
#   'funded_time': '2015-02-01 22:16:13+00:00',
#   'lender_count': 35},
#  {'id': 724331,
#   'posted_time': '2014-06-13 05:17:04+00:00',
#   'funded_time': '2014-06-18 10:06:38+00:00',
#   'lender_count': 10},
#  {'id': 825890,
#   'posted_time': '2015-01-09 07:24:56+00:00',
#   'funded_time': '2015-01-10 04:58:41+00:00',
#   'lender_count': 8},
#  {'id': 936438,
#   'posted_time': '2015-08-21 12:09:56+00:00',
#   'funded_time': None,
#   'lender_count': 6},
#  {'id': 1264813,
#   'posted_time': '2017-03-23 08:01:44+00:00',
#   'funded_time': '2017-03-29 08:01:29+00:00',
#   'lender_count': 3},
#  {'id': 1108039,
#   'posted_time': '2016-06-28 14:13:19+00:00',
#   'funded_time': '2016-07-25 09:22:13+00:00',
#   'lender_count': 24},
#  {'id': 983458,
#   'posted_time': '2015-11-23 09:23:27+00:00',
#   'funded_time': '2015-12-10 02:26:12+00:00',
#   'lender_count': 12},
#  {'id': 938148,
#   'posted_time': '2015-08-25 08:54:46+00:00',
#   'funded_time': '2015-09-17 15:24:53+00:00',
#   'lender_count': 97},
#  {'id': 786844,
#   'posted_time': '2014-10-21 20:08:52+00:00',
#   'funded_time': None,
#   'lender_count': 8},
#  {'id': 685483,
#   'posted_time': '2014-03-18 15:21:13+00:00',
#   'funded_time': '2014-04-17 06:59:24+00:00',
#   'lender_count': 18},
#  {'id': 698345,
#   'posted_time': '2014-04-16 05:58:58+00:00',
#   'funded_time': '2014-04-19 16:19:23+00:00',
#   'lender_count': 13},
#  {'id': 761151,
#   'posted_time': '2014-08-27 22:36:18+00:00',
#   'funded_time': None,
#   'lender_count': 11},
#  {'id': 863634,
#   'posted_time': '2015-03-30 06:54:08+00:00',
#   'funded_time': '2015-04-07 13:05:50+00:00',
#   'lender_count': 10},
#  {'id': 1112828,
#   'posted_time': '2016-07-07 15:35:57+00:00',
#   'funded_time': '2016-07-19 17:46:03+00:00',
#   'lender_count': 5},
#  {'id': 1174508,
#   'posted_time': '2016-10-25 17:33:24+00:00',
#   'funded_time': '2016-11-07 07:55:58+00:00',
#   'lender_count': 4},
#  {'id': 1119154,
#   'posted_time': '2016-07-19 16:12:37+00:00',
#   'funded_time': '2016-08-07 20:17:36+00:00',
#   'lender_count': 8},
#  {'id': 837192,
#   'posted_time': '2015-02-06 15:47:34+00:00',
#   'funded_time': '2015-02-26 01:45:20+00:00',
#   'lender_count': 27},
#  {'id': 1075130,
#   'posted_time': '2016-05-25 09:46:13+00:00',
#   'funded_time': '2016-05-30 17:48:35+00:00',
#   'lender_count': 5},
#  {'id': 978162,
#   'posted_time': '2015-11-13 08:18:53+00:00',
#   'funded_time': '2015-11-25 10:16:12+00:00',
#   'lender_count': 11},
#  {'id': 771688,
#   'posted_time': '2014-09-19 08:28:21+00:00',
#   'funded_time': '2014-09-25 19:28:52+00:00',
#   'lender_count': 7},
#  {'id': 1230031,
#   'posted_time': '2017-01-31 13:39:33+00:00',
#   'funded_time': '2017-02-06 15:12:14+00:00',
#   'lender_count': 20},
#  {'id': 840237,
#   'posted_time': '2015-02-13 03:07:08+00:00',
#   'funded_time': '2015-02-25 19:40:46+00:00',
#   'lender_count': 11},
#  {'id': 852629,
#   'posted_time': '2015-03-09 20:40:09+00:00',
#   'funded_time': None,
#   'lender_count': 28},
#  {'id': 933601,
#   'posted_time': '2015-08-18 01:29:13+00:00',
#   'funded_time': '2015-08-27 16:02:18+00:00',
#   'lender_count': 23},
#  {'id': 956051,
#   'posted_time': '2015-09-30 21:48:16+00:00',
#   'funded_time': None,
#   'lender_count': 10},
#  {'id': 1286564,
#   'posted_time': '2017-04-26 08:56:35+00:00',
#   'funded_time': '2017-05-06 16:24:20+00:00',
#   'lender_count': 7},
#  {'id': 709555,
#   'posted_time': '2014-05-13 21:52:42+00:00',
#   'funded_time': None,
#   'lender_count': 9},
#  {'id': 929855,
#   'posted_time': '2015-08-10 10:04:28+00:00',
#   'funded_time': '2015-08-28 15:42:37+00:00',
#   'lender_count': 18},
#  {'id': 671094,
#   'posted_time': '2014-02-17 12:08:23+00:00',
#   'funded_time': '2014-02-19 01:59:36+00:00',
#   'lender_count': 16},
#  {'id': 1257511,
#   'posted_time': '2017-03-15 02:06:11+00:00',
#   'funded_time': '2017-03-18 18:18:09+00:00',
#   'lender_count': 7},
#  {'id': 667651,
#   'posted_time': '2014-02-10 14:14:31+00:00',
#   'funded_time': '2014-02-20 14:57:02+00:00',
#   'lender_count': 35},
#  {'id': 995472,
#   'posted_time': '2015-12-15 11:34:58+00:00',
#   'funded_time': None,
#   'lender_count': 73},
#  {'id': 823647,
#   'posted_time': '2015-01-04 01:55:57+00:00',
#   'funded_time': '2015-01-05 19:40:50+00:00',
#   'lender_count': 26},
#  {'id': 689111,
# ...
#   'funded_time': '2014-03-07 23:43:31+00:00',
#   'lender_count': 6},
#  {'id': 1019048,
#   'posted_time': '2016-02-05 15:38:32+00:00',
#   'funded_time': '2016-02-22 18:30:05+00:00',
#   'lender_count': 37},
#  {'id': 775777,
#   'posted_time': '2014-09-27 02:10:50+00:00',
#   'funded_time': None,
#   'lender_count': 39},
#  {'id': 726573,
#   'posted_time': '2014-06-18 01:42:38+00:00',
#   'funded_time': '2014-07-14 04:06:08+00:00',
#   'lender_count': 29},
#  {'id': 1244318,
#   'posted_time': '2017-02-22 22:41:00+00:00',
#   'funded_time': '2017-02-26 01:48:21+00:00',
#   'lender_count': 24},
#  {'id': 1251308,
#   'posted_time': '2017-03-06 12:22:48+00:00',
#   'funded_time': '2017-03-19 13:25:08+00:00',
#   'lender_count': 14},
#  {'id': 773504,
#   'posted_time': '2014-09-23 11:42:41+00:00',
#   'funded_time': '2014-09-30 01:54:46+00:00',
#   'lender_count': 24},
#  {'id': 861480,
#   'posted_time': '2015-03-25 11:31:16+00:00',
#   'funded_time': '2015-04-05 10:56:46+00:00',
#   'lender_count': 15},
#  {'id': 1239177,
#   'posted_time': '2017-02-15 18:01:09+00:00',
#   'funded_time': '2017-02-21 00:16:11+00:00',
#   'lender_count': 19},
#  {'id': 997051,
#   'posted_time': '2015-12-18 04:23:22+00:00',
#   'funded_time': '2015-12-21 23:27:51+00:00',
#   'lender_count': 12},
#  {'id': 665498,
#   'posted_time': '2014-02-04 17:01:52+00:00',
#   'funded_time': '2014-02-07 14:10:58+00:00',
#   'lender_count': 9},
#  {'id': 751003,
#   'posted_time': '2014-08-07 11:13:59+00:00',
#   'funded_time': '2014-08-20 14:28:20+00:00',
#   'lender_count': 6},
#  {'id': 668540,
#   'posted_time': '2014-02-12 01:05:54+00:00',
#   'funded_time': '2014-02-24 23:04:34+00:00',
#   'lender_count': 1},
#  {'id': 1246467,
#   'posted_time': '2017-02-26 00:00:00+00:00',
#   'funded_time': None,
#   'lender_count': 0},
#  {'id': 1190403,
#   'posted_time': '2016-11-22 13:17:52+00:00',
#   'funded_time': None,
#   'lender_count': 12},
#  {'id': 994471,
#   'posted_time': '2015-12-14 07:15:58+00:00',
#   'funded_time': '2015-12-18 03:15:09+00:00',
#   'lender_count': 8},
#  {'id': 1126155,
#   'posted_time': '2016-07-29 12:48:43+00:00',
#   'funded_time': '2016-08-11 03:42:34+00:00',
#   'lender_count': 8},
#  {'id': 792444,
#   'posted_time': '2014-10-31 10:11:12+00:00',
#   'funded_time': '2014-11-06 12:39:11+00:00',
#   'lender_count': 6},
#  {'id': 906662,
#   'posted_time': '2015-06-23 12:37:58+00:00',
#   'funded_time': '2015-07-23 16:00:28+00:00',
#   'lender_count': 11},
#  {'id': 744103,
#   'posted_time': '2014-07-24 02:50:39+00:00',
#   'funded_time': '2014-08-26 13:32:27+00:00',
#   'lender_count': 41},
#  {'id': 1319757,
#   'posted_time': '2017-06-14 13:12:54+00:00',
#   'funded_time': '2017-06-24 21:11:02+00:00',
#   'lender_count': 6},
#  {'id': 889803,
#   'posted_time': '2015-05-22 02:26:47+00:00',
#   'funded_time': '2015-05-29 13:22:54+00:00',
#   'lender_count': 85},
#  {'id': 1210172,
#   'posted_time': '2016-12-24 16:11:15+00:00',
#   'funded_time': '2016-12-25 02:47:18+00:00',
#   'lender_count': 18},
#  {'id': 1213875,
#   'posted_time': '2016-12-31 06:11:04+00:00',
#   'funded_time': '2017-01-17 17:51:24+00:00',
#   'lender_count': 12},
#  {'id': 1209653,
#   'posted_time': '2016-12-23 08:22:40+00:00',
#   'funded_time': '2016-12-27 08:25:51+00:00',
#   'lender_count': 6},
#  {'id': 1038846,
#   'posted_time': '2016-03-15 15:30:03+00:00',
#   'funded_time': '2016-03-21 04:38:00+00:00',
#   'lender_count': 23},
#  {'id': 941338,
#   'posted_time': '2015-09-01 05:09:35+00:00',
#   'funded_time': '2015-09-10 05:30:05+00:00',
#   'lender_count': 13},
#  {'id': 664148,
#   'posted_time': '2014-01-30 19:55:14+00:00',
#   'funded_time': '2014-02-04 19:23:32+00:00',
#   'lender_count': 8},
#  {'id': 813641,
#   'posted_time': '2014-12-11 18:03:05+00:00',
#   'funded_time': '2014-12-22 01:27:05+00:00',
#   'lender_count': 108},
#  {'id': 1016562,
#   'posted_time': '2016-02-01 05:16:28+00:00',
#   'funded_time': '2016-02-02 22:22:05+00:00',
#   'lender_count': 10},
#  {'id': 1209294,
#   'posted_time': '2016-12-22 19:28:55+00:00',
#   'funded_time': '2016-12-23 23:06:42+00:00',
#   'lender_count': 8},
#  {'id': 976808,
#   'posted_time': '2015-11-11 06:51:01+00:00',
#   'funded_time': '2015-12-11 05:17:13+00:00',
#   'lender_count': 27},
#  {'id': 847337,
#   'posted_time': '2015-02-26 08:33:23+00:00',
#   'funded_time': '2015-03-06 08:45:04+00:00',
#   'lender_count': 7},
#  {'id': 1257429,
#   'posted_time': '2017-03-14 21:58:22+00:00',
#   'funded_time': '2017-03-26 18:19:13+00:00',
#   'lender_count': 34},
#  {'id': 790670,
#   'posted_time': '2014-10-29 01:35:21+00:00',
#   'funded_time': '2014-11-25 03:26:38+00:00',
#   'lender_count': 25},
#  {'id': 1225642,
#   'posted_time': '2017-01-24 06:47:12+00:00',
#   'funded_time': '2017-01-27 19:43:36+00:00',
#   'lender_count': 9},
#  {'id': 973967,
#   'posted_time': '2015-11-05 08:59:12+00:00',
#   'funded_time': '2015-12-02 02:41:20+00:00',
#   'lender_count': 49},
#  {'id': 939064,
#   'posted_time': '2015-08-27 06:16:44+00:00',
#   'funded_time': '2015-08-30 15:39:50+00:00',
#   'lender_count': 8},
#  {'id': 1040182,
#   'posted_time': '2016-03-17 08:37:33+00:00',
#   'funded_time': '2016-04-18 19:27:44+00:00',
#   'lender_count': 36},
#  {'id': 985658,
#   'posted_time': '2015-11-26 04:15:58+00:00',
#   'funded_time': '2015-12-29 17:38:55+00:00',
#   'lender_count': 32},
#  {'id': 851952,
#   'posted_time': '2015-03-07 07:37:30+00:00',
#   'funded_time': '2015-03-19 23:57:17+00:00',
#   'lender_count': 8},
#  {'id': 1121902,
#   'posted_time': '2016-07-22 21:44:23+00:00',
#   'funded_time': '2016-08-20 20:37:34+00:00',
#   'lender_count': 90},
#  {'id': 1120643,
#   'posted_time': '2016-07-21 09:28:35+00:00',
#   'funded_time': '2016-08-23 19:00:55+00:00',
#   'lender_count': 20},
#  {'id': 731639,
#   'posted_time': '2014-06-27 08:48:57+00:00',
#   'funded_time': '2014-07-11 00:32:31+00:00',
#   'lender_count': 9},
#  {'id': 1183102,
#   'posted_time': '2016-11-10 09:53:51+00:00',
#   'funded_time': '2016-11-21 15:32:32+00:00',
#   'lender_count': 50},
#  {'id': 1154955,
#   'posted_time': '2016-09-21 19:36:53+00:00',
#   'funded_time': '2016-09-30 13:25:46+00:00',
#   'lender_count': 11},
#  {'id': 955839,
#   'posted_time': '2015-09-30 15:05:48+00:00',
#   'funded_time': '2015-10-03 00:56:44+00:00',
#   'lender_count': 5},
#  {'id': 1198076,
#   'posted_time': '2016-12-03 17:30:16+00:00',
#   'funded_time': None,
#   'lender_count': 9},
#  {'id': 687988,
#   'posted_time': '2014-03-24 06:38:20+00:00',
#   'funded_time': '2014-03-28 22:47:26+00:00',
#   'lender_count': 11},
#  {'id': 1168800,
#   'posted_time': '2016-10-17 06:39:41+00:00',
#   'funded_time': '2016-10-23 00:57:28+00:00',
#   'lender_count': 1},
#  {'id': 1305949,
#   'posted_time': '2017-05-24 17:03:45+00:00',
#   'funded_time': '2017-05-27 05:07:16+00:00',
#   'lender_count': 9},
#  {'id': 1159893,
#   'posted_time': '2016-09-28 20:30:42+00:00',
#   'funded_time': '2016-10-25 18:44:26+00:00',
#   'lender_count': 34},
#  {'id': 1200596,
#   'posted_time': '2016-12-08 05:39:21+00:00',
#   'funded_time': '2016-12-17 07:00:03+00:00',
#   'lender_count': 19},
#  {'id': 747294,
#   'posted_time': '2014-07-31 03:52:55+00:00',
#   'funded_time': '2014-08-06 13:49:29+00:00',
#   'lender_count': 6},
#  {'id': 1300075,
#   'posted_time': '2017-05-17 09:55:46+00:00',
#   'funded_time': '2017-06-21 16:05:04+00:00',
#   'lender_count': 23},
#  {'id': 1207274,
#   'posted_time': '2016-12-20 15:25:56+00:00',
#   'funded_time': '2016-12-25 04:14:03+00:00',
#   'lender_count': 13},
#  {'id': 668173,
#   'posted_time': '2014-02-11 08:33:18+00:00',
#   'funded_time': '2014-03-04 15:18:24+00:00',
#   'lender_count': 6},
#  {'id': 1224187,
#   'posted_time': '2017-01-21 01:23:05+00:00',
#   'funded_time': '2017-01-22 18:16:18+00:00',
#   'lender_count': 1},
#  {'id': 688466,
#   'posted_time': '2014-03-24 17:18:41+00:00',
#   'funded_time': '2014-04-11 05:01:14+00:00',
#   'lender_count': 15},
#  {'id': 1229454,
#   'posted_time': '2017-01-31 02:00:18+00:00',
#   'funded_time': '2017-01-31 08:46:53+00:00',
#   'lender_count': 6},
#  {'id': 713834,
#   'posted_time': '2014-05-21 16:10:00+00:00',
#   'funded_time': '2014-05-26 08:33:25+00:00',
#   'lender_count': 10},
#  {'id': 1076376,
#   'posted_time': '2016-05-26 15:21:37+00:00',
#   'funded_time': None,
#   'lender_count': 2},
#  {'id': 1034085,
#   'posted_time': '2016-03-06 07:11:04+00:00',
#   'funded_time': '2016-03-18 22:06:35+00:00',
#   'lender_count': 13},
#  {'id': 668391,
#   'posted_time': '2014-02-11 14:02:33+00:00',
#   'funded_time': '2014-03-04 18:53:09+00:00',
#   'lender_count': 4},
#  {'id': 1284236,
#   'posted_time': '2017-04-24 02:10:10+00:00',
#   'funded_time': '2017-05-18 16:28:58+00:00',
#   'lender_count': 31},
#  {'id': 1229902,
#   'posted_time': '2017-01-31 11:17:59+00:00',
#   'funded_time': '2017-02-27 05:32:36+00:00',
#   'lender_count': 10},
#  {'id': 1059275,
#   'posted_time': '2016-04-22 19:08:48+00:00',
#   'funded_time': '2016-05-18 01:11:36+00:00',
#   'lender_count': 14},
#  {'id': 744483,
#   'posted_time': '2014-07-24 14:29:25+00:00',
#   'funded_time': '2014-07-24 14:50:11+00:00',
#   'lender_count': 1},
#  {'id': 1181383,
#   'posted_time': '2016-11-08 00:56:35+00:00',
#   'funded_time': '2016-11-09 21:02:21+00:00',
#   'lender_count': 45},
#  {'id': 1196888,
#   'posted_time': '2016-12-01 06:14:07+00:00',
#   'funded_time': '2016-12-08 00:55:12+00:00',
#   'lender_count': 1},
#  {'id': 1026430,
#   'posted_time': '2016-02-22 05:07:57+00:00',
#   'funded_time': '2016-03-03 02:14:10+00:00',
#   'lender_count': 13},
#  {'id': 892599,
#   'posted_time': '2015-05-27 07:45:02+00:00',
#   'funded_time': '2015-06-17 12:40:48+00:00',
#   'lender_count': 12},
#  {'id': 1098416,
#   'posted_time': '2016-06-13 05:38:51+00:00',
#   'funded_time': '2016-06-19 16:31:01+00:00',
#   'lender_count': 7},
#  {'id': 784099,
#   'posted_time': '2014-10-16 09:08:05+00:00',
#   'funded_time': '2014-10-21 02:52:11+00:00',
#   'lender_count': 17},
#  {'id': 1112061,
#   'posted_time': '2016-07-06 04:57:08+00:00',
#   'funded_time': '2016-08-15 15:20:38+00:00',
#   'lender_count': 49},
#  {'id': 708888,
#   'posted_time': '2014-05-12 16:32:07+00:00',
#   'funded_time': '2014-05-23 23:05:13+00:00',
#   'lender_count': 20},
#  {'id': 798781,
#   'posted_time': '2014-11-14 19:48:01+00:00',
#   'funded_time': '2015-01-08 15:51:12+00:00',
#   'lender_count': 28},
#  {'id': 1111652,
#   'posted_time': '2016-07-05 07:49:40+00:00',
#   'funded_time': '2016-08-10 16:52:11+00:00',
#   'lender_count': 20},
#  {'id': 836172,
#   'posted_time': '2015-02-04 20:48:49+00:00',
#   'funded_time': '2015-02-25 19:58:43+00:00',
#   'lender_count': 44},
#  {'id': 1116142,
#   'posted_time': '2016-07-14 07:06:50+00:00',
#   'funded_time': '2016-07-23 22:09:30+00:00',
#   'lender_count': 6},
#  {'id': 1173205,
#   'posted_time': '2016-10-24 09:55:55+00:00',
#   'funded_time': '2016-12-08 17:33:48+00:00',
#   'lender_count': 29},
#  {'id': 664337,
#   'posted_time': '2014-01-31 06:59:57+00:00',
#   'funded_time': '2014-02-27 19:46:11+00:00',
#   'lender_count': 7},
#  {'id': 1155799,
#   'posted_time': '2016-09-22 14:36:12+00:00',
#   'funded_time': '2016-09-28 21:04:24+00:00',
#   'lender_count': 5},
#  {'id': 708140,
#   'posted_time': '2014-05-09 15:21:39+00:00',
#   'funded_time': '2014-05-15 07:26:36+00:00',
#   'lender_count': 43},
#  {'id': 1072820,
#   'posted_time': '2016-05-20 22:05:11+00:00',
#   'funded_time': '2016-05-31 18:02:38+00:00',
#   'lender_count': 4},
#  {'id': 928588,
#   'posted_time': '2015-08-06 08:40:24+00:00',
#   'funded_time': '2015-08-17 17:10:07+00:00',
#   'lender_count': 16},
#  {'id': 768693,
#   'posted_time': '2014-09-15 13:10:10+00:00',
#   'funded_time': '2014-10-14 18:23:45+00:00',
#   'lender_count': 15},
#  {'id': 1209449,
#   'posted_time': '2016-12-23 03:26:01+00:00',
#   'funded_time': '2016-12-26 23:31:31+00:00',
#   'lender_count': 5},
#  {'id': 1002751,
#   'posted_time': '2015-12-31 10:22:52+00:00',
#   'funded_time': '2016-01-28 10:14:00+00:00',
#   'lender_count': 26},
#  {'id': 939276,
#   'posted_time': '2015-08-27 11:55:37+00:00',
#   'funded_time': '2015-09-04 17:33:49+00:00',
#   'lender_count': 4},
#  {'id': 824734,
#   'posted_time': '2015-01-07 08:45:19+00:00',
#   'funded_time': '2015-01-13 11:49:28+00:00',
#   'lender_count': 7},
#  {'id': 979396,
#   'posted_time': '2015-11-16 11:45:56+00:00',
#   'funded_time': '2015-11-25 08:32:56+00:00',
#   'lender_count': 4},
#  {'id': 666247,
#   'posted_time': '2014-02-06 11:32:57+00:00',
#   'funded_time': '2014-02-17 17:44:11+00:00',
#   'lender_count': 109},
#  {'id': 992662,
#   'posted_time': '2015-12-10 02:00:54+00:00',
#   'funded_time': '2015-12-13 16:19:52+00:00',
#   'lender_count': 7},
#  {'id': 828827,
#   'posted_time': '2015-01-16 11:59:12+00:00',
#   'funded_time': '2015-01-18 01:55:22+00:00',
#   'lender_count': 4},
#  {'id': 1215375,
#   'posted_time': '2017-01-04 15:20:54+00:00',
#   'funded_time': None,
#   'lender_count': 40},
#  {'id': 1194122,
#   'posted_time': '2016-11-28 04:06:43+00:00',
#   'funded_time': '2016-12-23 03:21:27+00:00',
#   'lender_count': 21},
#  {'id': 996831,
#   'posted_time': '2015-12-17 23:44:03+00:00',
#   'funded_time': '2016-01-19 21:03:00+00:00',
#   'lender_count': 19},
#  {'id': 1113389,
#   'posted_time': '2016-07-08 11:35:42+00:00',
#   'funded_time': None,
#   'lender_count': 5},
#  {'id': 798326,
#   'posted_time': '2014-11-14 03:32:08+00:00',
#   'funded_time': '2014-11-25 03:15:19+00:00',
#   'lender_count': 14},
#  {'id': 995307,
#   'posted_time': '2015-12-15 07:04:48+00:00',
#   'funded_time': '2015-12-21 23:55:07+00:00',
#   'lender_count': 63},
#  {'id': 951795,
#   'posted_time': '2015-09-22 14:44:56+00:00',
#   'funded_time': '2015-09-30 22:31:07+00:00',
#   'lender_count': 14},
#  {'id': 1212959,
#   'posted_time': '2016-12-29 15:03:43+00:00',
#   'funded_time': '2016-12-31 11:17:33+00:00',
#   'lender_count': 5},
#  {'id': 1226400,
#   'posted_time': '2017-01-25 01:33:16+00:00',
#   'funded_time': '2017-01-25 20:33:25+00:00',
#   'lender_count': 3},
#  {'id': 1119239,
#   'posted_time': '2016-07-19 20:54:49+00:00',
#   'funded_time': '2016-08-18 02:45:51+00:00',
#   'lender_count': 13},
#  {'id': 677511,
#   'posted_time': '2014-02-27 08:57:57+00:00',
#   'funded_time': '2014-03-05 15:40:14+00:00',
#   'lender_count': 7},
#  {'id': 1198966,
#   'posted_time': '2016-12-06 06:09:28+00:00',
#   'funded_time': '2016-12-29 03:29:13+00:00',
#   'lender_count': 19},
#  {'id': 1303805,
#   'posted_time': '2017-05-23 02:26:48+00:00',
#   'funded_time': '2017-05-30 00:13:19+00:00',
#   'lender_count': 4},
#  {'id': 726484,
#   'posted_time': '2014-06-17 17:23:35+00:00',
#   'funded_time': '2014-07-22 02:59:00+00:00',
#   'lender_count': 11},
#  {'id': 908170,
#   'posted_time': '2015-06-25 14:39:40+00:00',
#   'funded_time': '2015-07-23 00:39:37+00:00',
#   'lender_count': 52},
#  {'id': 1184156,
#   'posted_time': '2016-11-14 03:12:56+00:00',
#   'funded_time': None,
#   'lender_count': 3},
#  {'id': 751024,
#   'posted_time': '2014-08-07 11:51:25+00:00',
#   'funded_time': '2014-08-14 04:08:23+00:00',
#   'lender_count': 9},
#  {'id': 1015271,
#   'posted_time': '2016-01-28 09:06:31+00:00',
#   'funded_time': '2016-02-25 17:31:57+00:00',
#   'lender_count': 18},
#  {'id': 1293358,
#   'posted_time': '2017-05-05 14:50:31+00:00',
#   'funded_time': '2017-05-19 04:46:26+00:00',
#   'lender_count': 11},
#  {'id': 1043692,
#   'posted_time': '2016-03-24 05:27:03+00:00',
#   'funded_time': '2016-03-29 21:52:31+00:00',
#   'lender_count': 4},
#  {'id': 1001575,
#   'posted_time': '2015-12-29 09:59:31+00:00',
#   'funded_time': '2015-12-29 22:46:43+00:00',
#   'lender_count': 36},
#  {'id': 798154,
#   'posted_time': '2014-11-13 18:00:28+00:00',
#   'funded_time': '2014-11-17 21:54:39+00:00',
#   'lender_count': 29},
#  {'id': 672680,
#   'posted_time': '2014-02-19 09:19:17+00:00',
#   'funded_time': '2014-02-21 21:30:33+00:00',
#   'lender_count': 34},
#  {'id': 729563,
#   'posted_time': '2014-06-24 01:25:24+00:00',
#   'funded_time': '2014-06-26 06:47:51+00:00',
#   'lender_count': 5},
#  {'id': 1287099,
#   'posted_time': '2017-04-26 21:36:27+00:00',
#   'funded_time': '2017-05-04 19:37:42+00:00',
#   'lender_count': 7},
#  {'id': 943189,
#   'posted_time': '2015-09-04 02:15:30+00:00',
#   'funded_time': '2015-09-06 15:44:49+00:00',
#   'lender_count': 1},
#  {'id': 1317515,
#   'posted_time': '2017-06-10 08:16:48+00:00',
#   'funded_time': None,
#   'lender_count': 0},
#  {'id': 874705,
#   'posted_time': '2015-04-23 10:00:37+00:00',
#   'funded_time': '2015-05-17 20:12:35+00:00',
#   'lender_count': 29},
#  {'id': 781533,
#   'posted_time': '2014-10-10 23:00:40+00:00',
#   'funded_time': '2014-10-14 21:13:42+00:00',
#   'lender_count': 7},
#  ...]

# %%
## checking single entry of crowd
jsondata['data']['crowd'][:2]
# Out:
# [{'id': 658776,
#   'posted_time': '2014-01-17 21:21:10+00:00',
#   'funded_time': '2014-02-05 17:57:55+00:00',
#   'lender_count': 33},
#  {'id': 1314847,
#   'posted_time': '2017-06-07 02:02:41+00:00',
#   'funded_time': '2017-06-21 17:10:38+00:00',
#   'lender_count': 9}]

# %%
## making crowd a dataframe
crowd = pd.DataFrame(jsondata['data']['crowd'])
crowd
# Out:
#            id                posted_time                funded_time  \
# 0      658776  2014-01-17 21:21:10+00:00  2014-02-05 17:57:55+00:00
# 1     1314847  2017-06-07 02:02:41+00:00  2017-06-21 17:10:38+00:00
# 2      863063  2015-03-27 20:08:04+00:00  2015-04-04 15:01:22+00:00
# 3     1184347  2016-11-14 07:32:12+00:00  2016-11-25 03:07:13+00:00
# 4      729745  2014-06-24 07:35:46+00:00  2014-07-10 16:12:43+00:00
# ...       ...                        ...                        ...
# 9995   679499  2014-03-05 07:05:38+00:00  2014-03-13 01:01:41+00:00
# 9996   873525  2015-04-22 06:32:13+00:00                       None
# 9997   917686  2015-07-15 11:53:33+00:00  2015-08-14 11:45:40+00:00
# 9998   905789  2015-06-22 07:44:18+00:00  2015-07-14 00:20:45+00:00
# 9999  1216411  2017-01-06 06:54:07+00:00  2017-01-08 01:17:28+00:00
#
#       lender_count
# 0               33
# 1                9
# 2                1
# 3               47
# 4               12
# ...            ...
# 9995            11
# 9996             6
# 9997            44
# 9998            11
# 9999             1
#
# [10000 rows x 4 columns]

# %%
## making demographics a dataframe
demo = pd.DataFrame(jsondata['data']['demographics'])
demo
# Out:
#            id      country                         region  \
# 0      658776  El Salvador              Ciudad El Triunfo
# 1     1314847  Philippines          Bais, Negros Oriental
# 2      863063         Peru                     Huarochiri
# 3     1184347      Armenia                  Vanadzor town
# 4      729745       Uganda                        Masindi
# ...       ...          ...                            ...
# 9995   679499     Pakistan                         Lahore
# 9996   873525        Kenya                       Machakos
# 9997   917686      Senegal                           None
# 9998   905789  Philippines  Binalbagan, Negros Occidental
# 9999  1216411  Philippines                  Carmen, Bohol
#
#                                        borrower_genders
# 0                                                  male
# 1                                                female
# 2     female, female, female, female, female, female...
# 3                                                female
# 4                                                female
# ...                                                 ...
# 9995                                             female
# 9996                   male, male, female, female, male
# 9997                                     female, female
# 9998                                             female
# 9999                                             female
#
# [10000 rows x 4 columns]

# %%
## making financials a dataframe
financials = pd.DataFrame(jsondata['data']['financials'])
financials
# Out:
#            id funded_amount currency  term_in_months
# 0      658776       $1000.0      USD            20.0
# 1     1314847        $225.0      PHP            13.0
# 2      863063       $1150.0      PEN             6.0
# 3     1184347       $1700.0      AMD            26.0
# 4      729745        $400.0      UGX             8.0
# ...       ...           ...      ...             ...
# 9995   679499         400.0      PKR            12.0
# 9996   873525         375.0      KES            14.0
# 9997   917686        1375.0      XOF             8.0
# 9998   905789         450.0      PHP            13.0
# 9999  1216411         125.0      PHP            16.0
#
# [10000 rows x 4 columns]

# %%
## making use a dataframe
use = pd.DataFrame(jsondata['data']['use'])
use
# Out:
#            id                   activity        sector  \
# 0      658776                    Vehicle  Personal Use
# 1     1314847                       Pigs   Agriculture
# 2      863063                  Bookstore        Retail
# 3     1184347                Photography      Services
# 4      729745              Fuel/Firewood        Retail
# ...       ...                        ...           ...
# 9995   679499        Fruits & Vegetables          Food
# 9996   873525                    Farming   Agriculture
# 9997   917686               Fish Selling          Food
# 9998   905789              General Store        Retail
# 9999  1216411  Personal Housing Expenses       Housing
#
#                                                     use
# 0     to purchase a motorcycle in order to travel fr...
# 1     to buy feed and other supplies like vitamins t...
# 2                  to buy notebooks, pencils, and pens.
# 3     to pay for a new lens for providing photograph...
# 4                             to buy  firewood to sell.
# ...                                                 ...
# 9995        to help her husband buy onions for resale.
# 9996  to buy fertilizer and pesticides to boost his ...
# 9997                                           buy fish
# 9998                     to buy more groceries to sell.
# 9999  to buy cement, hollow blocks, GI sheets, sand,...
#
# [10000 rows x 4 columns]

# %% [markdown]
# ## Transform

# %%
financials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              10000 non-null  int64
#  1   funded_amount   10000 non-null  object
#  2   currency        10000 non-null  object
#  3   term_in_months  10000 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 312.6+ KB

# %%
## fixing funded amount column
financials['funded_amount'] = financials['funded_amount'].str.replace('$','').astype(float)
financials
# Out:
# /var/folders/td/cybzgn316hq8r5cn05lb0y2m0000gn/T/ipykernel_9337/858925245.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   financials['funded_amount'] = financials['funded_amount'].str.replace('$','').astype(float)
#            id  funded_amount currency  term_in_months
# 0      658776         1000.0      USD            20.0
# 1     1314847          225.0      PHP            13.0
# 2      863063         1150.0      PEN             6.0
# 3     1184347         1700.0      AMD            26.0
# 4      729745          400.0      UGX             8.0
# ...       ...            ...      ...             ...
# 9995   679499          400.0      PKR            12.0
# 9996   873525          375.0      KES            14.0
# 9997   917686         1375.0      XOF             8.0
# 9998   905789          450.0      PHP            13.0
# 9999  1216411          125.0      PHP            16.0
#
# [10000 rows x 4 columns]

# %% [markdown]
# ## Load

# %%
## loading mysql credentials
with open('/Users/purvikansara/.secret/mysql.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['username', 'password'])

# %%
## creating connection to database with sqlalchemy
from urllib.parse import quote_plus as urlquote
connection  = f"mysql+pymysql://{login['username']}:{urlquote(login['password'])}@localhost/belt_exam"
engine = create_engine(connection)

# %%
## Check if database exists, if not, create it
if database_exists(connection):
    print('It exists!')
else:
    create_database(connection)
    print('Database created!')
# Out:
# It exists!

# %%
## saving dataframes to database
financials.to_sql('financials', engine, index=False, if_exists = 'replace')
# Out:
# 10000

# %%
use.to_sql('use', engine, index=False, if_exists = 'replace')
demo.to_sql('demographics', engine, index=False, if_exists = 'replace')
crowd.to_sql('crowd',engine, index=False, if_exists = 'replace')
# Out:
# 10000

# %%
## checking if tables created
q='''SHOW TABLES;'''
pd.read_sql(q,engine)
# Out:
#   Tables_in_belt_exam
# 0               crowd
# 1        demographics
# 2          financials
# 3                 use

# %%
q='''SELECT * FROM demographics;'''
pd.read_sql(q,engine)
# Out:
#            id      country                         region  \
# 0      658776  El Salvador              Ciudad El Triunfo
# 1     1314847  Philippines          Bais, Negros Oriental
# 2      863063         Peru                     Huarochiri
# 3     1184347      Armenia                  Vanadzor town
# 4      729745       Uganda                        Masindi
# ...       ...          ...                            ...
# 9995   679499     Pakistan                         Lahore
# 9996   873525        Kenya                       Machakos
# 9997   917686      Senegal                           None
# 9998   905789  Philippines  Binalbagan, Negros Occidental
# 9999  1216411  Philippines                  Carmen, Bohol
#
#                                        borrower_genders
# 0                                                  male
# 1                                                female
# 2     female, female, female, female, female, female...
# 3                                                female
# 4                                                female
# ...                                                 ...
# 9995                                             female
# 9996                   male, male, female, female, male
# 9997                                     female, female
# 9998                                             female
# 9999                                             female
#
# [10000 rows x 4 columns]

# %% [markdown]
# # Hypothesis Testing

# %% [markdown]
# ### State the Hypothesis & Null Hypothesis

# %% [markdown]
# - $H_0$ (Null Hypothesis): Funded amount is the same for teams that contain at least 1 female and teams that are all male.
# - $H_A$ (Alternative Hypothesis): There is a significant difference between the funded amount for teams that contain at least 1 female and teams that are all male.

# %% [markdown]
# - Based upon the [Choosing the Right Hypothesis Test workflow from  the LP]( https://login.codingdojo.com/m/376/12533/88117):
#     - **The appropriate test to perform would be:**
#         - Since we are measuring a numeric quantity (funded amount)
#         - and we are comparing 2 groups/samples.
#         - We therefore want to perform a 2-sample t-test, A.K.A. an independent t-test.
#
# - **According the the work flow, the 2-sample T-Test has the following assumptions:**
#     - No significant outliers
#     - Normality
#     - Equal Variance

# %% [markdown]
# ## Getting the Group Data

# %% [markdown]
# - The next step is to get the data for each group in separate variables. All of the approaches below will lead to the same result: a `male_df` and `female_df` variable.

# %% [markdown]
# ### Approach 1: Using the MySQL Database to Get DF to Filter

# %%
q = """SELECT 
    f.id, f.funded_amount, d.borrower_genders
FROM
    financials AS f
        JOIN
    demographics AS d ON f.id = d.id;"""
df = pd.read_sql(q,engine)
df
# Out:
#            id  funded_amount  \
# 0      658776         1000.0
# 1     1314847          225.0
# 2      863063         1150.0
# 3     1184347         1700.0
# 4      729745          400.0
# ...       ...            ...
# 9995  1033255         1000.0
# 9996   998024          150.0
# 9997   771844          225.0
# 9998   679499          400.0
# 9999   917686         1375.0
#
#                                        borrower_genders
# 0                                                  male
# 1                                                female
# 2     female, female, female, female, female, female...
# 3                                                female
# 4                                                female
# ...                                                 ...
# 9995                                               male
# 9996                                             female
# 9997                                             female
# 9998                                             female
# 9999                                     female, female
#
# [10000 rows x 3 columns]

# %%
## Create a column that defines the 2 groups, has female or not
df['has_female'] = df['borrower_genders'].str.contains('female', case=False)
df
# Out:
#            id  funded_amount  \
# 0      658776         1000.0
# 1     1314847          225.0
# 2      863063         1150.0
# 3     1184347         1700.0
# 4      729745          400.0
# ...       ...            ...
# 9995  1033255         1000.0
# 9996   998024          150.0
# 9997   771844          225.0
# 9998   679499          400.0
# 9999   917686         1375.0
#
#                                        borrower_genders has_female
# 0                                                  male      False
# 1                                                female       True
# 2     female, female, female, female, female, female...       True
# 3                                                female       True
# 4                                                female       True
# ...                                                 ...        ...
# 9995                                               male      False
# 9996                                             female       True
# 9997                                             female       True
# 9998                                             female       True
# 9999                                     female, female       True
#
# [10000 rows x 4 columns]

# %%
## Separate the column of interest based on the groups
male_df = df.loc[ df['has_female']==False, ['funded_amount','has_female']]
female_df = df.loc[ df['has_female']==True, ['funded_amount','has_female']]
print(f"There are {len(female_df)} campaigns that had females on the team." )
print(f"There are {len(male_df)} campaigns that only had males on the team." )
# Out:
# There are 7820 campaigns that had females on the team.
# There are 2119 campaigns that only had males on the team.

# %% [markdown]
# ### Approach 2: Using the MySQL database to make the male_df and female_df

# %% [markdown]
# >- Due to a quirk with using "%" with sqlalchemy queries, in order to use a LIKE command with "%" for "%female":
#     1. Add quotation marks around the "%" expression.
#     ```python
#     q = '''SELECT
#     f.funded_amount, d.borrower_genders
# FROM
#     financials AS f
#         JOIN
#     demographics AS d ON f.id = d.id
# WHERE
#     d.borrower_genders LIKE "%female%";'''
#     ```
#     2. Use the sqlalchemy text function when running your query.
#     ```python
#     from sqlalchemy import text
#     female_df = pd.read_sql(text(q),engine)
#     ```

# %%
## importing text function to use on query with a "%" in it
from sqlalchemy import text

# %%
## query to get campaigns that included female borrowers
q = '''SELECT 
    f.funded_amount,  
    d.borrower_genders LIKE "%female%" as "has_female"
FROM
    financials AS f
        JOIN
    demographics AS d ON f.id = d.id
WHERE
    d.borrower_genders LIKE "%female%";'''
female_df = pd.read_sql(text(q),engine)
female_df
# Out:
#       funded_amount  has_female
# 0             225.0           1
# 1            1150.0           1
# 2            1700.0           1
# 3             400.0           1
# 4             350.0           1
# ...             ...         ...
# 7815          400.0           1
# 7816          375.0           1
# 7817         1375.0           1
# 7818          450.0           1
# 7819          125.0           1
#
# [7820 rows x 2 columns]

# %%
## query to get campaigns that were only male borrowers
q = """SELECT 
    f.funded_amount, 
    d.borrower_genders LIKE "%female%" as "has_female"

FROM
    financials AS f
        JOIN
    demographics AS d ON f.id = d.id
WHERE
    d.borrower_genders NOT LIKE '%female%';"""
male_df = pd.read_sql(text(q),engine)
male_df
# Out:
#       funded_amount  has_female
# 0            1000.0           0
# 1             925.0           0
# 2             875.0           0
# 3             600.0           0
# 4             375.0           0
# ...             ...         ...
# 2114         1000.0           0
# 2115          800.0           0
# 2116          125.0           0
# 2117          100.0           0
# 2118         3000.0           0
#
# [2119 rows x 2 columns]

# %%
print(f"There are {len(female_df)} campaigns that had females on the team." )
print(f"There are {len(male_df)} campaigns that only had males on the team." )
# Out:
# There are 7820 campaigns that had females on the team.
# There are 2119 campaigns that only had males on the team.

# %% [markdown]
# ### Approach 3: Use pd.merge to join the DataFrames

# %%
df = pd.merge(financials, demo, on='id')
df
# Out:
#            id  funded_amount currency  term_in_months      country  \
# 0      658776         1000.0      USD            20.0  El Salvador
# 1     1314847          225.0      PHP            13.0  Philippines
# 2      863063         1150.0      PEN             6.0         Peru
# 3     1184347         1700.0      AMD            26.0      Armenia
# 4      729745          400.0      UGX             8.0       Uganda
# ...       ...            ...      ...             ...          ...
# 9995   679499          400.0      PKR            12.0     Pakistan
# 9996   873525          375.0      KES            14.0        Kenya
# 9997   917686         1375.0      XOF             8.0      Senegal
# 9998   905789          450.0      PHP            13.0  Philippines
# 9999  1216411          125.0      PHP            16.0  Philippines
#
#                              region  \
# 0                 Ciudad El Triunfo
# 1             Bais, Negros Oriental
# 2                        Huarochiri
# 3                     Vanadzor town
# 4                           Masindi
# ...                             ...
# 9995                         Lahore
# 9996                       Machakos
# 9997                           None
# 9998  Binalbagan, Negros Occidental
# 9999                  Carmen, Bohol
#
#                                        borrower_genders
# 0                                                  male
# 1                                                female
# 2     female, female, female, female, female, female...
# 3                                                female
# 4                                                female
# ...                                                 ...
# 9995                                             female
# 9996                   male, male, female, female, male
# 9997                                     female, female
# 9998                                             female
# 9999                                             female
#
# [10000 rows x 7 columns]

# %%
df['has_female'] = df['borrower_genders'].str.contains('female', case=False)
df
# Out:
#            id  funded_amount currency  term_in_months      country  \
# 0      658776         1000.0      USD            20.0  El Salvador
# 1     1314847          225.0      PHP            13.0  Philippines
# 2      863063         1150.0      PEN             6.0         Peru
# 3     1184347         1700.0      AMD            26.0      Armenia
# 4      729745          400.0      UGX             8.0       Uganda
# ...       ...            ...      ...             ...          ...
# 9995   679499          400.0      PKR            12.0     Pakistan
# 9996   873525          375.0      KES            14.0        Kenya
# 9997   917686         1375.0      XOF             8.0      Senegal
# 9998   905789          450.0      PHP            13.0  Philippines
# 9999  1216411          125.0      PHP            16.0  Philippines
#
#                              region  \
# 0                 Ciudad El Triunfo
# 1             Bais, Negros Oriental
# 2                        Huarochiri
# 3                     Vanadzor town
# 4                           Masindi
# ...                             ...
# 9995                         Lahore
# 9996                       Machakos
# 9997                           None
# 9998  Binalbagan, Negros Occidental
# 9999                  Carmen, Bohol
#
#                                        borrower_genders has_female
# 0                                                  male      False
# 1                                                female       True
# 2     female, female, female, female, female, female...       True
# 3                                                female       True
# 4                                                female       True
# ...                                                 ...        ...
# 9995                                             female       True
# 9996                   male, male, female, female, male       True
# 9997                                     female, female       True
# 9998                                             female       True
# 9999                                             female       True
#
# [10000 rows x 8 columns]

# %%
## Separate the column of interest based on the groups
male_df = df.loc[ df['has_female']==False, ['funded_amount','has_female']]
female_df = df.loc[ df['has_female']==True,['funded_amount','has_female']]

print(f"There are {len(female_df)} campaigns that had females on the team." )
print(f"There are {len(male_df)} campaigns that only had males on the team." )
# Out:
# There are 7820 campaigns that had females on the team.
# There are 2119 campaigns that only had males on the team.

# %% [markdown]
# ## Visualize Group Means

# %%
## concatenate the two dataframes for visualziation.
plot_df = pd.concat([male_df, female_df], axis=0)
plot_df
# Out:
#       funded_amount has_female
# 0            1000.0      False
# 8             925.0      False
# 18            875.0      False
# 22            600.0      False
# 32            375.0      False
# ...             ...        ...
# 9995          400.0       True
# 9996          375.0       True
# 9997         1375.0       True
# 9998          450.0       True
# 9999          125.0       True
#
# [9939 rows x 2 columns]

# %%
## visualizing means. ci=68 makes easier to compare error bars (will discuss in class)
ax = sns.barplot(data=plot_df, x='has_female', y='funded_amount', ci=95)

# %%
## now that we have visualized the groups, we can save a final male_group and female_group
# that are a pandas Series. This will make the rest of our workflow simpler than if 
# we still had a dataframe

female_group = female_df['funded_amount']
male_group = male_df['funded_amount']
display(female_group.head(), male_group.head())
# Out:
# 1     225.0
# 2    1150.0
# 3    1700.0
# 4     400.0
# 5     350.0
# Name: funded_amount, dtype: float64
# 0     1000.0
# 8      925.0
# 18     875.0
# 22     600.0
# 32     375.0
# Name: funded_amount, dtype: float64

# %% [markdown]
# ## Checking Assumptions of 2-Sample T-test

# %% [markdown]
# - **According the the work flow, the 2-sample T-Test has the following assumptions:**
#     - No significant outliers
#     - Normality
#     - Equal Variance

# %% [markdown]
# ### Checking for Outliers

# %% [markdown]
# - Check each group SEPARATELY!

# %%
## Checking for abs vlaue of z-scores that are > 3
is_outlier_females = np.abs(stats.zscore(female_group)) > 3
print(f"There are {is_outlier_females.sum()} outliers in the female group out of {len(female_group)})")
# Out:
# There are 202 outliers in the female group out of 7820)

# %%
female_df.loc[~is_outlier_females]
# Out:
#       funded_amount has_female
# 1             225.0       True
# 2            1150.0       True
# 3            1700.0       True
# 4             400.0       True
# 5             350.0       True
# ...             ...        ...
# 9995          400.0       True
# 9996          375.0       True
# 9997         1375.0       True
# 9998          450.0       True
# 9999          125.0       True
#
# [7618 rows x 2 columns]

# %%
## removing outliers from female_group
female_group = female_group.loc[~is_outlier_females]
female_group
# Out:
# 1        225.0
# 2       1150.0
# 3       1700.0
# 4        400.0
# 5        350.0
#          ...
# 9995     400.0
# 9996     375.0
# 9997    1375.0
# 9998     450.0
# 9999     125.0
# Name: funded_amount, Length: 7618, dtype: float64

# %%
## Checking for abs vlaue of z-scores that are > 3
is_outlier_males = np.abs(stats.zscore(male_group)) > 3
print(f"There are {is_outlier_males.sum()} outliers in the male group of out of {len(male_group)}.")
# Out:
# There are 26 outliers in the male group of out of 2119.

# %%
## removing outliers from male_group
male_group = male_group.loc[~is_outlier_males]
male_group
# Out:
# 0       1000.0
# 8        925.0
# 18       875.0
# 22       600.0
# 32       375.0
#          ...
# 9984    1000.0
# 9985     800.0
# 9991     125.0
# 9992     100.0
# 9993    3000.0
# Name: funded_amount, Length: 2093, dtype: float64

# %% [markdown]
# ### Checking for Normality

# %% [markdown]
# - According to the workflow on the LP, since both groups have n > 15, we can safely ignore the assumption of normality.

# %% [markdown]
# ### Checking for Equal Variance

# %%
result = stats.levene(male_group, female_group)
print(result)
print(result.pvalue<.05)
# Out:
# LeveneResult(statistic=5.919603200045773, pvalue=0.014991261165002913)
# True

# %% [markdown]
# - According to the documentation for stats.levene, the null hypothesis for the test is that both groups have equal variance. Since our p-value is less than .05 we reject that null hypothesis and conclude that our groups do NOT have equal variance.
#
# - Since we did NOT meet the assumption of equal variance, we will run our stats.ttest_ind using equal_var=False. This will run a Welch's T-Test, which is designed to account for unequal variance.

# %% [markdown]
# ## Statistical Test

# %%
result = stats.ttest_ind(male_group, female_group, equal_var=False)
print(result)
result.pvalue < .05
# Out:
# Ttest_indResult(statistic=4.5701408946264275, pvalue=5.046604720900298e-06)
# True

# %% [markdown]
# ## Final Conclusion

# %% [markdown]
# - Our Welch's T-Test return a p-value < .05 (it was actually p <.0001!) we reject the null hypothesis and support the alternative hypothesis that there is a significant difference in funded amounts for teams that included at least 1 female.
#
# - In order to know if they are funded significantly MORE or LESS, we look at the actual means of our final groups.

# %%
print(f"The average funded_amount for male groups was {male_group.mean():.2f}")
print(f"The average funded_amount for female groups was {female_group.mean():.2f}")
# Out:
# The average funded_amount for male groups was 712.06
# The average funded_amount for female groups was 640.80

# %% [markdown]
# - Male groups are funded at significantly higher amounts than female groups.

# %% [markdown]
# ## OPTIONAL - VIEWING THE BARPLOT WITHOUT OUTLIERS

# %%
## concatenate the two dataframes for visualziation.
plot_df = pd.concat([male_df.loc[~is_outlier_males], 
                     female_df.loc[~is_outlier_females]], axis=0)
plot_df
# Out:
#       funded_amount has_female
# 0            1000.0      False
# 8             925.0      False
# 18            875.0      False
# 22            600.0      False
# 32            375.0      False
# ...             ...        ...
# 9995          400.0       True
# 9996          375.0       True
# 9997         1375.0       True
# 9998          450.0       True
# 9999          125.0       True
#
# [9711 rows x 2 columns]

# %%
sns.barplot(data=plot_df, x='has_female',y='funded_amount')
# Out:
# <AxesSubplot:xlabel='has_female', ylabel='funded_amount'>
